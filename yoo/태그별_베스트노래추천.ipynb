# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd
from scipy.sparse import *
from scipy.sparse.linalg import svds
from tqdm import tqdm
from collections import Counter
from itertools import chain, combinations

# %%
#플레이 리스트
train = pd.read_json('data/train.json')
#곡 정보
song_meta = pd.read_json('data/song_meta.json')

# %%
display(train.head(1))
display(song_meta.head(1))
# Out:
#   tags     id plylst_title                                              songs  \
# 0  [락]  61281      여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
#
#    like_cnt                updt_date
# 0        71  2013-12-19 18:36:19.000
#   song_gn_dtl_gnr_basket  issue_date                    album_name  album_id  \
# 0               [GN0901]    20140512  불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
#
#   artist_id_basket song_name song_gn_gnr_basket artist_name_basket  id
# 0           [2727]  Feelings           [GN0900]  [Various Artists]   0

# %% [markdown]
# ## song_meta에 노래 빈도수 추가
# - 추천리스트에 많은 노래가 나왔을 때 추천 기준으로 삼을 수 있다.
# - popularity 컬럼으로 추가해준다.

# %%
#모든 노래를 하나의 리스트로 모은다
all_songs = np.concatenate(train['songs'])
#노래의 빈도수를 센다.
song_counts = dict(Counter(all_songs))

#popularity에 넣는다.
song_meta['popularity'] = song_meta['id'].apply(lambda x : song_counts.get(x) if song_counts.get(x) else 0)

# %% [markdown]
# # 희소행렬 만들기
# - 각 플레이리스트에 달린 태그 유무를 희소행렬로 표현한다.

# %%
#각 플레이리스트 보유 태그 수
train['tag_cnt']= train['tags'].apply(lambda x : len(x))

#중복을 제외한 태그 셋
all_tags_set = set(np.concatenate(train['tags']))

#태그를 list형으로 모은다.
tag_lists = train['tags'].tolist()

# %%
#태그 아이디 만들기
id_to_tag = dict(zip(range(len(all_tags_set)), all_tags_set))
tag_to_id = dict(zip(all_tags_set, range(len(all_tags_set)) ))

#태그를 할당된 id로 바꾼 list
id_tag_lists = [list(map(lambda x: tag_to_id[x] , tags)) for tags in train['tags']]

# %%
row = np.repeat(np.arange(len(train)), train['tag_cnt'].tolist())
col = np.concatenate(id_tag_lists)
data = np.ones(col.shape[0])


#희소 행렬 만들기
ply_tag = csr_matrix((data, (row, col)))
tag_ply = ply_tag.T

# %% [markdown]
# # 태그 입력, 곡의 빈도수 기반 추천 - 세부과정
# 1. **사용자로부터 태그를 입력받는다.** -> ***`input_tag_id`***
#     - `len(tag_cnt) >= 2`
#     - `len(tag_cnt) == 1`
# 2. **각 태그가 속한 플레이리스트의 곡들을 가져온다.**
#     - `플레이리스트 곡들의 총 합이 30곡 보다 작으면 중복제거 후 바로 제공` - *다음에*
# 3. **각 태그의 전체 곡들을 빈도수로 정렬하고 상위 n개로 자른다.** -> ***`popular_songs_each_tag`***
# 4. **각 곡모음 모든 조합의 교집합을 구한다.**
#     -  **?** 교집합 결과가 30곡 미만인 경우 - *다음에*
# 5. **결과 노래를 그대로 제공한다 (상위 노래일수록 많은 플레이리스에서 등장한 노래) or
#   ~~노래 `popularity`로 정렬하여 제공한다.~~**

# %% [markdown]
# ### **태그 입력받기**

# %%
input_tags = ['비오는날','이별','감성','저녁']

# is not None 조건으로 존재하지 않는 태그의 경우 반영하지 않는다.
input_tag_id = [tag_to_id.get(x) for x in input_tags if tag_to_id.get(x) is not None]
input_tag_id
# Out:
# [4106, 219, 1034, 2880]

# %% [markdown]
# ### **각 태그가 속한 플레이리스트 가져오기**

# %%
selected_playlists = []
for tag_id in input_tag_id:
    # tag_id인 열 가져오기
    temp_list = ply_tag[:,tag_id].toarray().reshape(-1)
    # 그 중 1인 것만 playlist에 넣기
    selected_playlists.append(np.argwhere(temp_list == 1).reshape(-1))

selected_playlists
# Out:
# [array([    18,     75,    118, ..., 114977, 115008, 115011], dtype=int64),
#  array([     6,     45,     55, ..., 115025, 115045, 115052], dtype=int64),
#  array([    16,     24,     42, ..., 115026, 115030, 115039], dtype=int64),
#  array([   198,    295,    338, ..., 114738, 114767, 114822], dtype=int64)]

# %% [markdown]
# ### **각 태그별 플레이리스트들의 노래를 하나의 리스트들로 만들고 빈도를 센다.**
# - 중복이 존재할 수 있다.

# %%
tag_playlist_songs = []
for playlist in selected_playlists:
    # 태그에 딸린 플레이리스트들의 곡을 합친 리스트.
    temp = np.concatenate(train.iloc[playlist]['songs'].tolist())
    tag_playlist_songs.append(temp)

# 각 노래리스트에서 빈도수를 센다. 
counts = []
for song in tag_playlist_songs:
    counts.append(dict(Counter(song)))

# %% [markdown]
# ### **각 노래들의 빈도 순위로 자르기**

# %%
popular_songs_each_tag = []
for count in counts:
    popular_songs_each_tag.append(sorted(count, key= count.get, reverse = True)[:200])

# %% [markdown]
# > `popular_songs_each_tag` - 각 태그가 붙은 플레이리스트에서 등장한 상위 500곡

# %% [markdown]
# ### **모든 조합의 교집합 구하기**

# %%
input_tag_cnt = len(input_tag_id)

# 모든 조합 구하기
combs = list(chain.from_iterable(combinations(popular_songs_each_tag, r) for r in range(2, (input_tag_cnt + 1))))

# %%
#조합을 순회하며 겹치는 노래들을 추천 플레이 리스트에 추가
#밑에 있을수록 다수의 플레이리스트에서 겹치는 노래다. -> reverse로 반대로 만든다.
rec_playlist = []
for comb in combs:
    rec_playlist.extend(list(set.intersection(*map(set,comb))))
rec_playlist.reverse()

print(f'중복 제거 전 곡 수 :{len(rec_playlist)}')

# 혹시 있을 중복을 제거한다.
# 순서를 유지하기 위해 df로 처리한다.
rec_df = pd.DataFrame(rec_playlist)
rec_df.drop_duplicates(inplace= True, ignore_index = True)

print(f'최종 결과 곡 수 :{len(rec_df)}')
# Out:
# 중복 제거 전 곡 수 :921
# 최종 결과 곡 수 :194

# %% [markdown]
# ### 최종 결과 곡들의 상위 30곡

# %%
song_meta.iloc[rec_df[0]][['song_name','artist_name_basket','popularity']].head(30)
# Out:
#                                 song_name            artist_name_basket  \
# 547967                                불안해                  [혜지 (Hyeji)]
# 235773           이 노래를 듣게 된다면 (Feat. 이소진)  [어쿠스틱 멜로디 (Acoustic Melody)]
# 68348                      손편지 (Vocal 태인)                          [아재]
# 703096          사랑에 연습이 있었다면 (Prod. 2soo)                         [임재현]
# 357367                                  비                          [폴킴]
# 38261                      한번쯤 (With 박은옥)                          [아재]
# 448116                         MOM (겨울나무)                          [홍아]
# 215411                 지금보다 조금 (Feat. 이원)  [어쿠스틱 멜로디 (Acoustic Melody)]
# 674160                  늦은 밤 너의 집 앞 골목길에서                          [노을]
# 209135                           소란했던 시절에                      [빌리어코스티]
# 351342                                  끝                         [권진아]
# 582252                  준비된 이별 (With 박은옥)                          [아재]
# 678762               꽃잎이 떨어지면 (Feat. 뜨때로)  [어쿠스틱 멜로디 (Acoustic Melody)]
# 154858                                 안녕                          [폴킴]
# 487911                Midnight (Feat. 민우)                          [아재]
# 616038                      그때의 나, 그때의 우리                       [어반자카파]
# 350309          Sad Movie (Vocal by Levi)              [업라이트 (Upright)]
# 108004                               언능언능                          [홍아]
# 13281   넌 이별 난 아직 (With 한소현 Of 3rd Coast)                      [스탠딩 에그]
# 600802                              비가 온다                         [정승환]
# 358241                        사랑이란 멜로는 없어                         [전상근]
# 668128                            사랑이 그리워                          [태인]
# 519391                         Love Again                         [김제훈]
# 199262                     후회 (Feat. 박은옥)                          [아재]
# 15318                         With Winter                       [민은서밴드]
# 65622                                포장마차                         [황인욱]
# 601037                               여기까지           [권진아, 샘김 (Sam Kim)]
# 427724              지워줄게 (Vocal by 스티브언니)                          [아재]
# 209993                            미련이 남아서                          [민우]
# 463173            비가 내렸어 (Vocal by 스티브언니)              [업라이트 (Upright)]
#
#         popularity
# 547967        1434
# 235773        1320
# 68348         1324
# 703096         837
# 357367        1981
# 38261         1060
# 448116        1368
# 215411        1408
# 674160        1119
# 209135        1312
# 351342        1203
# 582252        1380
# 678762        1207
# 154858        1112
# 487911        1307
# 616038         871
# 350309        1425
# 108004        1184
# 13281         1473
# 600802         918
# 358241        1007
# 668128        1402
# 519391        1251
# 199262        1333
# 15318         1198
# 65622          886
# 601037        1071
# 427724        1407
# 209993        1313
# 463173        1544

# %% [markdown]
# ### ~~최종 결과 곡들을 전체인기도로 정렬 후 상위 30곡~~
# - 아무데나 들어가는 국밥곡들이 있어서 이렇게는 안됨

# %%
song_meta.iloc[rec_df[0]][['song_name','artist_name_basket','popularity']].sort_values(by = 'popularity', ascending = False).head(30)
# Out:
#                                 song_name            artist_name_basket  \
# 144663                                밤편지                         [아이유]
# 116573                                안아줘                         [정준일]
# 357367                                  비                          [폴킴]
# 366786            가끔 미치도록 네가 안고 싶어질 때가 있어                        [가을방학]
# 349492                               어떤이별                         [임승부]
# 675115                                야생화                         [박효신]
# 463173            비가 내렸어 (Vocal by 스티브언니)              [업라이트 (Upright)]
# 42155                                 벙어리                          [홍아]
# 396828                               쉬운사랑                          [중신]
# 461341                             어떻게 지내                       [Crush]
# 174749              비도 오고 그래서 (Feat. 신용재)                 [헤이즈 (Heize)]
# 520093              고마운 사람 (Vocal by 이소진)              [업라이트 (Upright)]
# 485155                                 선물                          [민우]
# 523521                            사랑을 놓치고                         [박은옥]
# 13281   넌 이별 난 아직 (With 한소현 Of 3rd Coast)                      [스탠딩 에그]
# 648628           분홍빛 가득한 날에 (Vocal by 호수)                          [아재]
# 449244                                스토커                        [10CM]
# 680366              끝내지 못한 이야기 (Feat. 호수)  [어쿠스틱 멜로디 (Acoustic Melody)]
# 169984                         같은 시간 속의 너                          [나얼]
# 422915                                 연인                          [중신]
# 187047                                 착각                         [박은옥]
# 547967                                불안해                  [혜지 (Hyeji)]
# 422077                             너로 가득해                  [혜지 (Hyeji)]
# 350309          Sad Movie (Vocal by Levi)              [업라이트 (Upright)]
# 627363                          널 사랑하지 않아                       [어반자카파]
# 300087                     Madeleine Love                 [CHEEZE (치즈)]
# 215411                 지금보다 조금 (Feat. 이원)  [어쿠스틱 멜로디 (Acoustic Melody)]
# 427724              지워줄게 (Vocal by 스티브언니)                          [아재]
# 442014                           내 곁에 있어줘                          [중신]
# 668128                            사랑이 그리워                          [태인]
#
#         popularity
# 144663        2175
# 116573        2121
# 357367        1981
# 366786        1919
# 349492        1599
# 675115        1598
# 463173        1544
# 42155         1540
# 396828        1538
# 461341        1526
# 174749        1512
# 520093        1508
# 485155        1492
# 523521        1476
# 13281         1473
# 648628        1470
# 449244        1468
# 680366        1467
# 169984        1463
# 422915        1455
# 187047        1437
# 547967        1434
# 422077        1432
# 350309        1425
# 627363        1424
# 300087        1415
# 215411        1408
# 427724        1407
# 442014        1403
# 668128        1402

# %% [markdown]
# ---

# %% [markdown]
# # 테스트 해보기

# %%
def recommend(input_tags):  
    
    input_tag_id = [tag_to_id.get(x) for x in input_tags if tag_to_id.get(x) is not None]
    if not input_tag_id:
        print('입력하신 태그가 모두 존재하지 않습니다.')
        return 0
    
    selected_playlists = []
    for tag_id in input_tag_id:
        # tag_id인 열 가져오기
        temp_list = ply_tag[:,tag_id].toarray().reshape(-1)
        # 그 중 1인 것만 playlist에 넣기
        selected_playlists.append(np.argwhere(temp_list == 1).reshape(-1))

    tag_playlist_songs = []
    for playlist in selected_playlists:
        # 태그에 딸린 플레이리스트들의 곡을 합친 리스트.
        temp = np.concatenate(train.iloc[playlist]['songs'].tolist())
        tag_playlist_songs.append(temp)

    counts = []
    for song in tag_playlist_songs:
        counts.append(dict(Counter(song)))
        
    popular_songs_each_tag = []
    for count in counts:
        popular_songs_each_tag.append(sorted(count, key= count.get, reverse = True)[:200])
    
    
    # 인풋 태그가 한개면 그냥 상위 30곡 리턴
    input_tag_cnt = len(input_tag_id)
    if input_tag_cnt < 2:
        return song_meta.iloc[popular_songs_each_tag[0]][['song_name','artist_name_basket','popularity']].head(30)
    
    
    # 모든 조합 구하기
    combs = list(chain.from_iterable(combinations(popular_songs_each_tag, r) for r in range(2, (input_tag_cnt + 1))))

    rec_playlist = []
    for comb in combs:
        rec_playlist.extend(list(set.intersection(*map(set,comb))))
    rec_playlist.reverse()
        
    
    rec_df = pd.DataFrame(rec_playlist)
    rec_df.drop_duplicates(inplace= True, ignore_index = True)
    
    if len(rec_df) == 0:
        print('곡이 존재하지 않습니다.')
        return 0
    
    return song_meta.iloc[rec_df[0]][['song_name','artist_name_basket','popularity']].head(30)

# %% [markdown]
# ### 테스트 하려면 아래 셀을 실행

# %%
while True:
    test_tag = list(input('태그를 입력하세요(띄어쓰기 구분) :' ).split(' '))
    if not test_tag or test_tag == ['']:
        print('태그 입력하세요')
        continue
    else:
        r1 = recommend(test_tag)
        display(r1)
    break
# Out:
# 태그를 입력하세요(띄어쓰기 구분) : 크리스마스 캐롤 pop 팝 christmas xmas
#                                                 song_name  \
# 387859                    All I Want For Christmas Is You
# 358186                                      Santa Tell Me
# 579838                                           벌써 크리스마스
# 185211                             Baby It`s Cold Outside
# 667770                                      Bring Me Love
# 695032                                            크리스마스니까
# 213493              Let it Snow, Let it Snow, Let it Snow
# 320500                              Cozy Little Christmas
# 137969        It`s Beginning To Look A Lot Like Christmas
# 539630                      Santa Claus Is Coming To Town
# 226670                  Santa Claus Is Comin&#39; to Town
# 62574                                      This Christmas
# 83436                                HERE (For Christmas)
# 359783                                           첫눈이 온다구요
# 280293                              Love you on Christmas
# 335077                                      Merry & Happy
# 611679                                   Man With The Bag
# 332893                                        Let It Snow
# 452444                                   Joy To The World
# 587738                                      Christmas Day
# 542554                             잊지 말기로 해 (Bonus Track)
# 287705                            Like It&#39;s Christmas
# 328024  Only Thing I Ever Get For Christmas (Album Ver...
# 338900                                    Candy Cane Lane
# 637135             Have Yourself A Merry Little Christmas
# 61771                                             Snowman
# 21196                            something about december
# 117323       Text Me Merry Christmas (Feat. Kristen Bell)
# 152394             Let It Snow, Let It Snow, Let It Snow
# 600574                                         모두에게 크리스마스
#
#                                        artist_name_basket  popularity
# 387859                                     [Mariah Carey]         788
# 358186                                    [Ariana Grande]         694
# 579838  [케이윌, 소유 (SOYOU), 보이프렌드, 몬스타엑스, 우주소녀, 유승우, 브라더...         166
# 185211                      [Idina Menzel, Michael Buble]         142
# 667770                                      [John Legend]          84
# 695032                    [성시경, 박효신, 이석훈, 서인국, VIXX (빅스)]         839
# 213493                                   [제이레빗(J Rabbit)]          84
# 320500                                       [Katy Perry]          36
# 137969                                    [Michael Buble]         155
# 539630                                    [Michael Buble]          92
# 226670                                     [Mariah Carey]         279
# 62574                                      [태연 (TAEYEON)]         287
# 83436                                      [Lukas Graham]          49
# 359783                                              [손승연]         133
# 280293                                              [백예린]         231
# 335077                                     [TWICE (트와이스)]         199
# 611679                                         [Jessie J]          66
# 332893                                      [John Legend]          73
# 452444                                       [Pentatonix]          44
# 587738                                              [EXO]         334
# 542554                                         [성시경, 권진아]         586
# 287705                                   [Jonas Brothers]          47
# 328024                                    [Justin Bieber]          71
# 338900                                              [Sia]         103
# 637135                                        [Sam Smith]         199
# 61771                                               [Sia]         562
# 21196                                   [Christina Perri]          96
# 117323                               [Straight No Chaser]         304
# 152394                                    [Michael Buble]         147
# 600574      [성시경, 브라이언, 서인국, 박학기, 박장현 (VROMANCE), 황 프로젝트]         200
