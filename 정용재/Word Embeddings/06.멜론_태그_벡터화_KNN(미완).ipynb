# %%
import os
import json
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
with open('data/train.json',encoding='utf-8-sig') as f:
    train_dict = json.load(f)
    
with open('data/song_meta.json',encoding='utf-8-sig') as f:
    song_dict = json.load(f)
    
with open('data/genre_gn_all.json',encoding='utf-8-sig') as f:
    genre_dict = json.load(f)
    
train_df = pd.DataFrame.from_dict(train_dict)
song_df = pd.DataFrame.from_dict(song_dict)

# %%
train_df.head()
# Out:
#                                                 tags      id  \
# 0                                                [락]   61281
# 1                                           [추억, 회상]   10532
# 2                                          [까페, 잔잔한]   76951
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                               [댄스]   27616
#
#             plylst_title                                              songs  \
# 0                여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
# 1                요즘 너 말야  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  편하게, 잔잔하게 들을 수 있는 곡.-  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  크리스마스 분위기에 흠뻑 취하고 싶을때  [394031, 195524, 540149, 287984, 440773, 10033...
# 4               추억의 노래 ㅋ  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#    like_cnt                updt_date
# 0        71  2013-12-19 18:36:19.000
# 1         1  2014-12-02 16:19:42.000
# 2        17  2017-08-28 07:09:34.000
# 3        33  2019-12-05 15:15:18.000
# 4         9  2011-10-25 13:54:56.000

# %%
train_df['tags_cnt'] = train_df['tags'].map(lambda x : len(x))
train_df.head()
# Out:
#                                                 tags      id  \
# 0                                                [락]   61281
# 1                                           [추억, 회상]   10532
# 2                                          [까페, 잔잔한]   76951
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                               [댄스]   27616
#
#             plylst_title                                              songs  \
# 0                여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
# 1                요즘 너 말야  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  편하게, 잔잔하게 들을 수 있는 곡.-  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  크리스마스 분위기에 흠뻑 취하고 싶을때  [394031, 195524, 540149, 287984, 440773, 10033...
# 4               추억의 노래 ㅋ  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#    like_cnt                updt_date  tags_cnt
# 0        71  2013-12-19 18:36:19.000         1
# 1         1  2014-12-02 16:19:42.000         2
# 2        17  2017-08-28 07:09:34.000         2
# 3        33  2019-12-05 15:15:18.000        10
# 4         9  2011-10-25 13:54:56.000         1

# %%
from itertools import chain
from collections import Counter
tags_all = chain.from_iterable(train_df['tags'].tolist())
tags_unique = list(set(tags_all))
tags_counter = dict(Counter(tags_all))

# %%
len(tags_unique)
# Out:
# 29160

# %%
songs_all = chain.from_iterable(train_df['songs'].tolist())
songs_unique = sorted(list(set(songs_all)))
songs_counter = dict(Counter(songs_all))

# %%
songs_unique[:3]
# Out:
# [0, 3, 4]

# %%
song_to_id = dict(zip(songs_unique,range(len(songs_unique))))
id_to_song = dict(zip(range(len(songs_unique)),songs_unique))

# %%
def song_id_trans(x):
    return [song_to_id[v] for v in x]

train_df['new_song_id'] = train_df['songs'].map(song_id_trans)

# %%
train_df.head()
# Out:
#                                                 tags      id  \
# 0                                                [락]   61281
# 1                                           [추억, 회상]   10532
# 2                                          [까페, 잔잔한]   76951
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                               [댄스]   27616
#
#             plylst_title                                              songs  \
# 0                여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
# 1                요즘 너 말야  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  편하게, 잔잔하게 들을 수 있는 곡.-  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  크리스마스 분위기에 흠뻑 취하고 싶을때  [394031, 195524, 540149, 287984, 440773, 10033...
# 4               추억의 노래 ㅋ  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#    like_cnt                updt_date  tags_cnt  \
# 0        71  2013-12-19 18:36:19.000         1
# 1         1  2014-12-02 16:19:42.000         2
# 2        17  2017-08-28 07:09:34.000         2
# 3        33  2019-12-05 15:15:18.000        10
# 4         9  2011-10-25 13:54:56.000         1
#
#                                          new_song_id
# 0  [456704, 112732, 333158, 488440, 258853, 12127...
# 1  [375894, 587314, 431997, 104605, 338568, 21226...
# 2  [72132, 240434, 144495, 161861, 307991, 222934...
# 3  [342495, 169897, 469393, 250235, 383169, 87161...
# 4  [138494, 481095, 4399, 560460, 255877, 87448, ...

# %%
songs_all = chain.from_iterable(train_df['new_song_id'].tolist())
songs_unique = sorted(list(set(songs_all)))
songs_counter = dict(Counter(songs_all))

# %%
#  노래id에 달린 태그들을 넣을 딕셔너리 초기화
song_id_to_tags_dict = {i:[] for i in range(len(songs_unique))}

# %%
# 태그_id에 달린 장르id들을 list로 넣어주기
for new_song_id , tags in zip(train_df['new_song_id'].tolist(),train_df['tags'].tolist()):
    for id in new_song_id:
        song_id_to_tags_dict[id].extend(tags)
        
song_id_to_tags_dict
# Out:
# {0: ['비오는날', '드라이브', '비오는날', '추억', '회상'],
#  1: ['1',
#   '감성',
#   '듣기좋은',
#   '드라이브',
#   'Pop',
#   '여행',
#   '기분전환',
#   '팝',
#   '신나는',
#   '클럽',
#   '매장음악',
#   '드라이브',
#   'EDM모음',
#   '페스티벌',
#   '기분전환',
#   '스트레스',
#   '신나는',
#   'dance',
#   'house',
#   '여름',
#   'tropical',
#   '일렉',
#   '편집숍',
#   '힙스터',
#   '기분전환',
#   '운동',
#   '축제',
#   '클럽',
#   '운동',
#   'Festival',
#   'EDM',
#   '불금',
#   '페스티벌',
#   '파티',
#   '즐거운',
#   '신나는'],
#  2: ['뉴에이지', '뉴에이지'],
#  3: ['비오는날',
#   '재즈',
#   '락',
#   '발라드',
#   '휴식',
#   '리메이크',
#   '재즈',
#   '힐링송',
#   '힐링',
#   '기분전환',
#   '기분_전환',
#   '음악'],
#  4: ['클래식', '산책', '조깅'],
#  5: ['클래식', '코로나'],
#  6: ['위로', '발라드', '감성', '발라드'],
#  7: ['재즈힙합',
#   '인디',
#   '감성',
#   '유럽여행',
#   '유럽',
#   '여행',
#   'Chill',
#   '감성',
#   '밤',
#   '편안한',
#   'JAYJE',
#   '아날로그',
#   'Lofi',
#   '로파이',
#   '공부할때',
#   '배경음악',
#   'Chill',
#   '멜로우비트',
#   '재즈',
#   '멜로우힙합',
#   'Lofihiphop',
#   '재즈힙합',
#   '빈티지',
#   '빈티지감성',
#   '로파이',
#   'Lofi',
#   '새벽감성',
#   'Lofihiphop',
#   '로파이힙합',
#   '로파이',
#   'Summer',
#   '여름',
#   'Pop',
#   '힙합',
#   '마이너감성',
#   '재즈',
#   'Lofi',
#   '재즈힙합',
#   '로파이',
#   '휴식',
#   '알앤비',
#   '그루브',
#   '재지한',
#   '재즈힙합',
#   '팝',
#   '편안한',
#   '깊은밤',
#   '신용산',
#   '몰티드',
#   '카페투어',
#   '분위기있는',
#   '취향저격DJ',
#   'bgm',
#   '카페',
#   '밤',
#   '새벽',
#   'chillax',
#   '나른해지는',
#   'Lofi',
#   '힙스터',
#   '로파이',
#   '집중',
#   '감성',
#   '카페',
#   '잔잔한',
#   '분위기',
#   '작업',
#   'Lofi',
#   '편안한',
#   '공부',
#   'Chill',
#   '잔잔한',
#   '꿀잠',
#   '휴식',
#   '새벽',
#   '자정',
#   '0시',
#   '즐잠',
#   '감성',
#   '노곤노곤',
#   '코곰',
#   '감성',
#   '카페',
#   '잔잔한',
#   '인디음악',
#   '새벽',
#   '잠이안올때',
#   '인디',
#   '집중',
#   '따스한',
#   '노동요',
#   '주말',
#   '차분한',
#   '독서',
#   '작업',
#   'Lofi',
#   '재즈힙합',
#   '편안한',
#   '잔잔한',
#   'chillsound',
#   '새벽',
#   '오후',
#   '해질녘',
#   '로우파이',
#   '가사없는',
#   'Lofi',
#   '밤',
#   '드라이브',
#   '카페',
#   '유니크',
#   '잠',
#   '재즈',
#   'Lofi',
#   'Lofihiphop',
#   '힐링',
#   '릴렉스',
#   '재즈힙합',
#   '공부',
#   '수면',
#   '편안한',
#   '비오는날',
#   '잔잔한',
#   '감성',
#   '새벽',
#   '분위기',
#   '몽환',
#   '휴식',
#   'Lofi',
#   '공부',
#   '로파이',
#   '휴식',
#   '연주곡',
#   '멜로디좋은',
#   '드라이브',
#   'bgm',
#   '멜로디',
#   '사랑',
#   '이별',
#   '흔하지않은',
#   '연주곡모음',
#   '감성',
#   '밤',
#   '아침',
#   '분위기',
#   'Lofi',
#   '힐링',
#   '기분전환',
#   'lo_fi',
#   '로파이',
#   'Chill',
#   'Lofi',
#   '집중',
#   '감성',
#   '집중',
#   '감성',
#   '새벽',
#   'study',
#   'Jazz',
#   '휴식',
#   '기분전환',
#   '사랑',
#   '숙면',
#   'Chill',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '눈',
#   '카페',
#   '데이트',
#   '휴식',
#   '카페',
#   '새벽',
#   '기말고사',
#   '가사없는',
#   '산책',
#   '공부',
#   'Lofi',
#   '힙합',
#   '비오는날',
#   '겨울',
#   '밤',
#   '멜로우',
#   '여행',
#   '사랑',
#   '바다',
#   '재즈힙합',
#   '까페',
#   'Lofi',
#   'HipHop',
#   'Jazz',
#   'jazzhiphop',
#   '휴식',
#   '잔잔한',
#   '새벽',
#   '몽환적',
#   '감성',
#   '인디',
#   '힙합',
#   '감성',
#   '밤',
#   '새벽',
#   'RnBR',
#   '감각적인',
#   '잔잔한',
#   '몽환',
#   '우울',
#   '인디'],
#  8: ['감성',
#   'Pop',
#   '듀엣',
#   '감성',
#   'LOVE',
#   '로맨틱',
#   '러브',
#   'Pop',
#   'Valentine',
#   '발렌타인',
#   'Duet',
#   '팝',
#   '휴식',
#   '로맨틱',
#   '재즈',
#   '그루브',
#   '특별한',
#   '기분전환',
#   '영화',
#   '데이트',
#   '스무스',
#   '빈티지'],
#  9: ['재즈', '가을밤', '로맨틱', '빅밴드', '스윙'],
#  10: ['일렉',
#   'bonOBono',
#   '탈선',
#   '처방전',
#   'breakBad',
#   'EDM',
#   '클럽',
#   '클럽음악',
#   '일렉',
#   'EDM'],
#  11: ['좋은곡', '스트레스', '장르불문', '카카오톡', '기분전환', '일상', '오픈채팅', '트렌디', '팝', '신나는'],
#  12: ['Poppop',
#   'stress',
#   'Queen',
#   'Winter',
#   'housemusic',
#   '여름',
#   '아이돌',
#   '댄스',
#   '드라이브',
#   '청량한',
#   '신나는노래',
#   '흥폭발',
#   'ralalra',
#   '노랫말을듣는다',
#   '신나는',
#   '추억',
#   '기분전환',
#   '회상',
#   'LOVEMYSELF',
#   '나를사랑하자',
#   'kpop',
#   '감성',
#   'MAMAMOO',
#   '마마무',
#   '걸그룹',
#   '잔잔한',
#   '드라이브',
#   '여행',
#   '신나는',
#   '언더그라운드힙합',
#   '아이돌',
#   '운동해서',
#   '오후',
#   'POP_MUSIC',
#   '일렉트로닉댄스',
#   '기분전환',
#   '드라이브',
#   '걸그룹',
#   '아이돌',
#   '수록곡',
#   '좋은노래',
#   '믿고듣는',
#   '마마무',
#   '홀로',
#   '나홀로',
#   '댄스',
#   '아이돌노래',
#   '운동용',
#   '아이돌',
#   '운동',
#   '노래',
#   '스트레스',
#   '운동할때듣는음악',
#   '운동할때',
#   '갓마무',
#   '마마무',
#   '카드',
#   '악동뮤지션',
#   '투모로우바이투게더',
#   '위너',
#   '마마무',
#   '방탄소년단',
#   '아이유',
#   '아이콘',
#   '윤하',
#   '이하이',
#   '상쾌한',
#   '기분전환',
#   '여행',
#   'kpop',
#   'MAMAMOO',
#   '마마무',
#   '걸그룹',
#   '드라이브',
#   '여행',
#   '기분전환',
#   '여돌',
#   '댄스',
#   '신나는',
#   '매력짱',
#   '무대매너짱',
#   '마마무짱'],
#  13: ['스트레스', '해소음악'],
#  14: ['비오는날',
#   '힐링',
#   '휴식',
#   '감성',
#   '혼자',
#   '자기전',
#   '잔잔한',
#   '위로',
#   '나만알고싶은음악',
#   '이별',
#   '인디',
#   '휴식',
#   '힐링',
#   '잔잔한',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '잔잔한',
#   '이별',
#   '감성',
#   '사랑',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '비',
#   '우울',
#   '인디',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '눈오는밤',
#   '겨울밤',
#   '한국인디',
#   '가을밤',
#   '늦가을',
#   '인디',
#   '따뜻한',
#   '추운밤',
#   '감성',
#   '카페',
#   '잔잔한',
#   '연인',
#   '새벽',
#   '슬픔',
#   '위로',
#   '이별',
#   '힐링',
#   '휴식',
#   '추억',
#   '회상',
#   '인디음악',
#   '힙합',
#   '짝사랑',
#   '흔하지않은',
#   '짝사랑포기할때듣는음악',
#   '자기전에',
#   '인디',
#   '어쿠스틱',
#   '여름밤',
#   '잔잔한인디',
#   '공원',
#   '달콤한인디',
#   '인디',
#   '듀엣',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '잔잔한',
#   '힐링',
#   '추억',
#   '휴식',
#   '회상',
#   '슬픔',
#   '감성',
#   '이별',
#   '가을',
#   '잔잔한',
#   '버스에서',
#   '편안함',
#   '가을',
#   '새벽',
#   '잔잔함',
#   '추억',
#   '휴식',
#   '고요',
#   '쓸쓸함',
#   '가을밤',
#   '매장음악',
#   '까페',
#   '가을감성',
#   '가을',
#   '새벽감성',
#   '감성발라드',
#   '가을밤',
#   '집',
#   '슬픔',
#   '침대',
#   '이별',
#   '인디',
#   '힐링',
#   '휴식',
#   '잔잔한',
#   '감성',
#   '밤',
#   '혼자',
#   '잔잔한',
#   '새벽',
#   '잠들기전',
#   '인디',
#   '감성',
#   '눈물',
#   '발라드',
#   '추억',
#   '슬픈',
#   '사랑',
#   '이별',
#   '매장음악',
#   '까페',
#   '잔잔한',
#   '이별',
#   '감성',
#   '우울',
#   '발라드',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상'],
#  15: ['클래식'],
#  16: ['먹자', '놀자'],
#  17: ['해외차트', '시대별차트', '팝', '추억', '1960', 'Rock'],
#  18: ['연말', '겨울', '클래식', '훈훈', '크리스마스', '캐롤', '추위'],
#  19: ['일렉', '일렉', '팝'],
#  20: ['팝'],
#  21: ['2월',
#   '신곡',
#   '에이셉퍼그',
#   '케샤',
#   '코스모스미드나잇',
#   '루이톰린슨',
#   '메디슨비어',
#   'Pop',
#   '가요',
#   '메간트레이너',
#   '일본',
#   '도쿄',
#   '시부야',
#   'JPOP',
#   '제이팝'],
#  22: ['자신감',
#   '봄',
#   '샹송',
#   '파리',
#   '산책',
#   '봄날',
#   '프렌치팝',
#   '경쾌한',
#   '포근한',
#   '따뜻함',
#   '분위기있는',
#   '카페',
#   '로맨틱',
#   '샹송',
#   '월드뮤직',
#   '분위기',
#   '낭만',
#   '감성',
#   '카페',
#   '여유',
#   '산책',
#   '여행',
#   '프랑스',
#   '힐링',
#   '사랑',
#   '편안한',
#   '유럽',
#   '배경음악',
#   '매장음악',
#   '카페',
#   'bgm',
#   '브금',
#   '프랑스',
#   '도시',
#   '프렌치시크',
#   '시크',
#   '프렌치',
#   '프랑스',
#   'fran',
#   '프랑스어',
#   '감성',
#   '가야씨',
#   '팝'],
#  23: ['2019년',
#   '아이돌',
#   '2019년상반기',
#   '신나는',
#   '걸그룹',
#   '보이그룹',
#   '신나는',
#   '기분좋은',
#   '명곡',
#   '자체제작돌',
#   '9TEEN',
#   '캐럿',
#   '세븐틴',
#   '띵곡',
#   '수록곡',
#   '신나는',
#   '웹드라마',
#   '일상',
#   '명곡',
#   'OST',
#   '드라마',
#   '기분전환',
#   '즐거운',
#   '스트레스해소',
#   '댄스',
#   '2000년대',
#   '청량청량',
#   '감각적인',
#   '일렉',
#   '여름밤',
#   'kpop',
#   '케이팝',
#   '휴식',
#   '아이돌',
#   '댄스',
#   '드라이브',
#   '기분전환',
#   '신나는',
#   '감성',
#   '신나는',
#   '여름',
#   '아침',
#   '상쾌',
#   '노래',
#   '시원한',
#   '기분전환',
#   '신나는',
#   '여름',
#   '여행',
#   '드라이브',
#   '아이돌',
#   '신나는',
#   '에이틴',
#   '웹드라마',
#   '리플리',
#   '열일곱',
#   '옐로우',
#   '연플리',
#   '꽃엔딩',
#   '댄스',
#   '주말',
#   '발라드',
#   '힙합',
#   '감성',
#   '매장음악',
#   '카페',
#   '알앤비',
#   '운동',
#   '드라이브',
#   '여행',
#   '신나는',
#   '세븐틴',
#   '남자아이돌',
#   '갓세븐',
#   '타이틀곡',
#   '몬스타엑스',
#   '엔시티',
#   '엑스원',
#   'TXT',
#   '엑소',
#   '신나는',
#   '여름',
#   '여돌',
#   '남돌',
#   '아이돌',
#   '확인',
#   '최신',
#   '댄스곡',
#   '기분전환',
#   '신나는',
#   '힙합',
#   '감성',
#   '매장음악',
#   '카페',
#   '알앤비',
#   '운동',
#   '드라이브',
#   '여행',
#   '사랑',
#   '감성',
#   '오에스티',
#   '웹드라마',
#   '새벽',
#   'OST',
#   '웹드라마ost',
#   '오스트',
#   '발라드',
#   '인디',
#   '아이돌',
#   '아침',
#   '아이돌',
#   '댄스',
#   '2010년대',
#   '들썩들썩',
#   '모닝콜',
#   '흥부자',
#   '신나는',
#   'Happy_New_Year',
#   '이루리',
#   '소원',
#   '새해',
#   '여름',
#   '드라이브',
#   '멋지다',
#   '즐기다',
#   '남자아이돌',
#   '뿜뿜',
#   '하트',
#   '댄스댄스',
#   '설렘',
#   '빠져든다',
#   '따라잡기',
#   '보이그룹노래',
#   '걸그룹',
#   '아이돌',
#   '걸그룹댄스곡',
#   '아이돌의숨은명곡',
#   '보이그룹',
#   '아이돌명곡',
#   '힙합',
#   '매장음악',
#   '카페',
#   '알앤비',
#   '매장브금',
#   '운동',
#   '드라이브',
#   '매장용음악',
#   '여행',
#   '신나는',
#   '감성',
#   '가을',
#   '기분전환',
#   '드라이브',
#   '케이팝',
#   '세븐틴',
#   'kpop',
#   '헬스',
#   '스포츠',
#   '최신가요',
#   '운동',
#   '홈트',
#   '가요',
#   '최신곡',
#   '유산소',
#   '축제',
#   '여름',
#   '시원',
#   '청량',
#   '행복',
#   '상쾌',
#   '여행',
#   '댄스',
#   '클럽',
#   '홈트',
#   '운동',
#   '신나는',
#   '기분전환',
#   '드라이브',
#   '드라마ost',
#   '웹드라마ost',
#   '기분전환',
#   '신나는',
#   '1위못했지만',
#   '유명한',
#   '드라이브',
#   '차트역주행',
#   '대박나자',
#   '기분전환',
#   '신나는',
#   '댄스',
#   '신나는',
#   '댄스파티',
#   '빵댕이주의',
#   '내가듣고싶어서만든플레이리스트',
#   '눈물나는',
#   '공감',
#   '운동',
#   '드라이브',
#   '아이돌',
#   '신나는',
#   '흥겨운',
#   '아이돌',
#   '명장면',
#   '댄스',
#   '명곡',
#   'OST',
#   '경쾌한',
#   '드라마',
#   '신나는',
#   '드라마ost',
#   '인기있는',
#   '최고시청률',
#   '도깨비',
#   '스카이캐슬',
#   '드라이브',
#   '신나는',
#   '겨울',
#   '감성',
#   '아이돌',
#   '취향저격',
#   '새해',
#   '노래',
#   '휴식',
#   'BTS',
#   '아이돌',
#   '빅뱅',
#   '남자아이돌',
#   '비투비',
#   '명곡',
#   '명곡들',
#   '워너원',
#   '씨엔블루',
#   '엑소',
#   '방탄소년단',
#   '블랙핑크',
#   '트와이스',
#   '엑소',
#   '아이돌',
#   '밤',
#   '새벽',
#   '수뎡쓰',
#   'Lovelyz',
#   'BabySouL',
#   '이수정의',
#   '심야',
#   '까페',
#   '행복하자',
#   '케이팝',
#   '새해맞이',
#   '기분전환',
#   '아이돌',
#   'kpop',
#   '케이팝',
#   '시원함',
#   '청량',
#   '사이다',
#   '드라이브',
#   '기분전환',
#   '고인물',
#   '청량이',
#   '신나는',
#   '운동용',
#   '힙합',
#   '감성',
#   '매장음악',
#   '카페',
#   '알앤비',
#   '운동',
#   '드라이브',
#   '여행',
#   '사랑',
#   '신나는',
#   '배고픈건가',
#   '리스타트',
#   '두근두근',
#   '설렘',
#   '드라이브',
#   '기분전환',
#   '웹드라마ost',
#   '이런꽃같은엔딩',
#   '웹드라마',
#   '리플',
#   '플레이리스트',
#   '연애플레이리스트',
#   'whyost',
#   '에이틴',
#   '또한번엔딩',
#   '한입만ost',
#   '감성',
#   '가을',
#   '여름',
#   '휴식',
#   '댄스',
#   '드라이브',
#   '여행',
#   '설거지',
#   '더위',
#   '신나는',
#   '여름',
#   '시원한',
#   '청량',
#   '무더위',
#   '노동요',
#   '아이돌',
#   '신나는음악',
#   '인기곡',
#   '매장BGM',
#   '매장노래',
#   '신나는노래',
#   '매장음악',
#   '흥폭발',
#   '댄스곡',
#   '기분전환',
#   '드라이브',
#   '여름',
#   '장마',
#   '들썩들썩',
#   '음료',
#   '드라이브',
#   '청량',
#   '내적댄스',
#   '더위',
#   '바다',
#   '신나는',
#   '숨은명곡',
#   '세븐틴',
#   '기분전환',
#   '여름',
#   '신나는',
#   '홈트',
#   '스포츠',
#   '훌라후프',
#   '운동',
#   '다이어트',
#   '댄스',
#   '내적댄스',
#   '유산소',
#   '신나는',
#   '기분전환',
#   '잔잔한',
#   '기분전환',
#   '신나는',
#   '댄스',
#   'jh',
#   '발라드',
#   '기분전환',
#   '스무살'],
#  24: ['뉴에이지'],
#  25: ['휴식',
#   '감성',
#   '책',
#   '분위기',
#   '가을',
#   '크리미널마인드',
#   'OST',
#   '수사OST',
#   '비밀의숲OST',
#   '감성',
#   '새벽',
#   '새벽감성',
#   '달달',
#   '분위기',
#   '명곡',
#   'OST',
#   '드라마',
#   '잔잔',
#   '응원',
#   '겨울',
#   '감성',
#   '카페',
#   '위로',
#   '격려',
#   '인디',
#   'depressed',
#   '우울',
#   '위로',
#   'sad',
#   '슬픔',
#   '장르불문',
#   '공감',
#   '드라마ost',
#   '기분좋은',
#   '여름',
#   '감성',
#   'TVN드라마',
#   '잔잔한',
#   'OST',
#   '휴식',
#   '기분전환',
#   '사랑',
#   '신나는',
#   '우울',
#   '새벽',
#   '짝사랑',
#   '밤',
#   '새벽',
#   '힘들때',
#   '슬픔',
#   '지쳤을때',
#   '답답할때',
#   '이별',
#   '회상',
#   '스트레스',
#   '동백꽃필무렵',
#   '가을',
#   '잔잔한',
#   '인디OST',
#   '적적함',
#   'OST',
#   '사랑',
#   '이별',
#   '감성',
#   'OST',
#   '드라마',
#   '사랑',
#   '헬로루키',
#   '나만알고싶은',
#   '취향저격',
#   '신인뮤지션',
#   '더팬',
#   'R',
#   '인디밴드',
#   '트렌디',
#   '인디',
#   '일렉트로닉',
#   '비오는날',
#   '매장음악',
#   '밤',
#   '새벽',
#   '우울',
#   '분위기',
#   '퇴폐',
#   '섹시',
#   '비오는날',
#   '멜랑꼴리',
#   '슬픔',
#   '잔잔',
#   '직장인',
#   '특별한'],
#  26: ['아이돌', '인디음악', '트로트', '팝송', '사무실', '동요'],
#  27: ['스트레스', '일렉'],
#  28: ['인디포크',
#   '어쿠스틱',
#   '포크',
#   '베스트',
#   '에센셜',
#   '한국포크',
#   '인디',
#   '편안한',
#   '인디포크',
#   '휴식_힐링',
#   '감성',
#   '인디',
#   '발라드',
#   '휴식',
#   '감성',
#   '기분전환',
#   '가을',
#   '잔잔한'],
#  29: ['추억', 'JPOP', '애니메이션OST', 'OST'],
#  30: ['띵곡', '페이버릿', '명곡', '내적댄스유발'],
#  31: ['카페',
#   '취향저격',
#   '팝',
#   '음색',
#   '여자보컬',
#   '매력적인',
#   '기분전환',
#   '설렘',
#   '감미로운',
#   '고막여친',
#   '분위기의',
#   '밤',
#   '알앤비',
#   '귀르가즘',
#   'RnB',
#   '감각적인',
#   '섹시한',
#   '그루브한',
#   '음색깡패'],
#  32: ['배경음악',
#   'TV',
#   'bgm',
#   '광고',
#   '기분전환',
#   '팝',
#   '광고음악',
#   '축구',
#   '위닝일레븐',
#   'pes',
#   '느와르',
#   '팝',
#   '분위기',
#   '언더커버',
#   '어두운',
#   '섹시',
#   '액션',
#   '락',
#   '얼터너티브'],
#  33: ['겨울', '잔잔한', '소울', '알앤비', '재즈', '추억', '까페', '회상'],
#  34: ['록음악', '할로윈', '락', '락'],
#  35: ['얼리재즈', 'before1960', '초기', 'Jazz', '명곡', '재즈', '개척자', '명인'],
#  36: ['록메탈', '록', 'Metal', '메탈', 'Rock', '락'],
#  37: ['월드뮤직'],
#  38: ['팝'],
#  39: ['새벽',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '힙합',
#   '감성',
#   '새벽',
#   '새벽감성',
#   'Jazz',
#   '재즈',
#   '힐링',
#   '힙합',
#   '랩',
#   '구름많음',
#   '힙한_세련된',
#   '카페',
#   '감각적인',
#   '라운지_바',
#   '멜로우_그루비',
#   '부드러운_잔잔한',
#   '로멘틱',
#   '재즈힙합',
#   '힙합',
#   '랩',
#   '매장음악',
#   'Jazz',
#   'Pop',
#   '재즈',
#   '배경음악',
#   '감성힙합',
#   '밤',
#   '카페',
#   '드라이브',
#   'Chillhop',
#   '힐링',
#   'jazzhiphop',
#   '재즈힙합',
#   '로파이',
#   '힙합',
#   '랩',
#   '여행',
#   '기분전환',
#   '산책',
#   '힙합',
#   '카페음악',
#   '카페',
#   '알앤비',
#   'jazzhiphop',
#   '재즈힙합',
#   '힘내',
#   '밤',
#   '가을',
#   '새벽',
#   '재즈힙합',
#   '좋은음악',
#   '힙합',
#   '랩',
#   '기분전환',
#   '운전',
#   '드라이브',
#   '카페',
#   '여행',
#   '감성힙합',
#   '재즈',
#   '시부야케이',
#   'pub',
#   '재즈힙합',
#   '편안한',
#   '재즈힙합',
#   '아메리카노',
#   '카페',
#   '기분전환',
#   '운동',
#   '플레이리스트',
#   '그루브',
#   'HipHop',
#   '기분전환',
#   'jazzhiphop',
#   'groove',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '재즈힙합',
#   '매장음악',
#   '카페',
#   '일상',
#   '힙합',
#   '감성',
#   '기분',
#   '치유',
#   '휴식',
#   '위로',
#   '감성힙합',
#   '비트',
#   '재즈힙합',
#   'groove',
#   '힙합',
#   '랩',
#   '겨울',
#   '잔잔한'],
#  40: ['조용한곳에서',
#   '발라드',
#   '발라드',
#   '출근길',
#   '아침',
#   '달콤한',
#   '비오는날',
#   '잔잔함',
#   '김광석',
#   '기분전환',
#   '매장음악',
#   '카페',
#   '아침',
#   '휴식',
#   '카페',
#   '조용한장소',
#   '조용한곳',
#   '차안에서',
#   '조용한음악'],
#  41: ['이별에', '죽음과'],
#  42: ['집중', 'ASMR', '노동요', '명상', '사색', '공부', '독서', '필라테스', '숙면', '요가'],
#  43: ['감각적인'],
#  44: ['CCM'],
#  45: ['여름',
#   '휴식',
#   '기분전환',
#   '봄',
#   '사랑',
#   '기원',
#   '역주행',
#   'kpop',
#   '기분전환',
#   '발라드',
#   '감성',
#   '드라이브',
#   '발라드',
#   '따듯한',
#   '휴식',
#   '카페',
#   '여유',
#   '추운',
#   '커피',
#   '일상',
#   '편안한',
#   '오후',
#   '쌀쌀한',
#   '휴식',
#   '밤',
#   '새벽',
#   '새벽감성',
#   '봄비',
#   '잔잔한',
#   '밤새벽',
#   '감성',
#   '포근한',
#   '발라드',
#   '비오는날',
#   '겨울',
#   '휴식',
#   '매장음악',
#   '카페',
#   '잔잔한',
#   '취향저격',
#   '센치',
#   '노래',
#   '감성',
#   '프로포즈',
#   '연인',
#   '발라드',
#   '인디',
#   '사랑',
#   '신부',
#   '이벤트',
#   '사랑',
#   '신랑',
#   '고백',
#   '특별한날',
#   '프로포즈',
#   '2020',
#   '결혼식',
#   '축가',
#   '소개글',
#   '드라이브',
#   '랩',
#   '감성',
#   '드라이브',
#   '발라드',
#   '비오는날',
#   '봄',
#   '카페',
#   '발라드',
#   '봄비',
#   '2010년대',
#   '드라이브',
#   '노랫말을듣는다',
#   '감성발라드',
#   'ralalra',
#   '비오는날',
#   '잔잔한노래',
#   '눈오는날',
#   '감성발라드',
#   '갬성쩌는지금',
#   '눈물나는날',
#   '겨울',
#   '휴식',
#   '매장음악',
#   '카페',
#   '잔잔한',
#   '취향저격',
#   '커피',
#   '감성',
#   '띵곡만',
#   '사랑',
#   'kpop',
#   '드라이브',
#   '발라드',
#   '썸남',
#   '연인',
#   '커플',
#   '고백',
#   '설렘',
#   '사랑',
#   '썸',
#   '노래방',
#   '썸녀',
#   '시대불문',
#   '짬봉',
#   '장르불문',
#   '휴식',
#   '봄',
#   '발라드',
#   '드라이브',
#   '여행',
#   '사랑',
#   '까페',
#   '감성',
#   '밤',
#   '새벽',
#   '봄비',
#   '드라이브',
#   '그리움',
#   '저녁',
#   '숨은명곡',
#   '감성',
#   '눈물',
#   '잔잔한',
#   '새벽감성',
#   '인디음악',
#   '새벽',
#   '늦은밤',
#   '이별',
#   '발라드',
#   'kpop',
#   '기분전환',
#   '발라드',
#   '감성',
#   '잔잔한',
#   '인디음악',
#   '힘들때',
#   '위로',
#   '휴식',
#   '인디',
#   '카페음악',
#   '감성',
#   '카페',
#   '여유',
#   '감성노래',
#   '봄날',
#   '벚꽃',
#   '힐링',
#   '봄소풍',
#   '봄',
#   '가을_밤',
#   '기분전환',
#   '가을',
#   '인디',
#   '인디뮤직',
#   '집중',
#   '감성',
#   '카페',
#   '그루브',
#   '도시',
#   '작업',
#   '빈티지',
#   '충전',
#   '느낌',
#   '레트로',
#   '취항저격',
#   '출근길',
#   '매장음악',
#   '카페',
#   '잔잔한',
#   '아침마다',
#   '센치해진',
#   '감성',
#   '기분전환',
#   '커피숍',
#   '연말',
#   '감성',
#   '혼자',
#   '분위기',
#   '솔로',
#   '겨울노래',
#   '크리스마스',
#   '혼술',
#   '이별',
#   '외로움',
#   '감성',
#   '카페',
#   '주말',
#   '야경',
#   '밤새벽',
#   '저녁',
#   '밤',
#   '감성',
#   '봄',
#   '카페',
#   '오후',
#   '저녁',
#   '봄캐롤',
#   '사랑',
#   '분위기깡패',
#   '쌀쌀한',
#   '솔로',
#   '흐린날',
#   '노동요',
#   '카페',
#   '발라드',
#   '오후',
#   '잔잔한',
#   '감성',
#   '퇴근길',
#   '인디',
#   '겨울',
#   '따뜻하게',
#   '진짜',
#   '개취',
#   '내기준',
#   '결혼식',
#   '고민',
#   '축가',
#   '플레이리스트',
#   '혼자들어요',
#   '사랑감성',
#   '발라드감성',
#   '폭발주의',
#   '연인',
#   '결혼',
#   '축가',
#   '고백',
#   '사랑',
#   '프로포즈',
#   '애인',
#   '결혼식',
#   '휴식',
#   '봄',
#   '발라드',
#   '봄노래',
#   '벚꽃',
#   '힐링',
#   '설렘',
#   '감성',
#   '밤',
#   '카페',
#   '가사',
#   '밤새벽',
#   '저녁',
#   '부드러운',
#   '따뜻한',
#   '감성',
#   '카페',
#   '잔잔한',
#   '연인',
#   '새벽',
#   '슬픔',
#   '위로',
#   '이별',
#   '가을노래',
#   '바람',
#   '감성',
#   '프러포즈',
#   '달달',
#   '고백',
#   '사랑',
#   '저녁',
#   '밤',
#   '카페',
#   '라디오',
#   '드라이브',
#   '도시',
#   '노을',
#   '밤새벽',
#   '감성',
#   '감성',
#   '카페',
#   '봄노래',
#   '월요병',
#   '봄바람',
#   '드라이브',
#   '저녁',
#   '고백',
#   '감수성',
#   '오후',
#   '고음폭발',
#   '노래방추천곡',
#   '노래방남자노래',
#   '노래방에서',
#   '남자보컬',
#   '고음',
#   '노래방애창곡',
#   '흥하자아아아아아아아아아아',
#   '여행',
#   '출근길',
#   '저녁',
#   '노동요',
#   '아침',
#   '노을',
#   '피곤',
#   '감성',
#   '느낌있는',
#   '퇴근길',
#   '선선한',
#   '겨울',
#   '감성',
#   '잔잔한',
#   '매장',
#   '발라드',
#   '쓸쓸한',
#   '커피',
#   '출근길',
#   '이별',
#   '힐링',
#   '휴식',
#   '감성',
#   '발라드',
#   '잔잔한',
#   '발라드',
#   '노동요',
#   '카페',
#   '주말',
#   '연인',
#   '사랑',
#   '드라이브',
#   '데이트',
#   '느낌있는',
#   '오후',
#   '휴식',
#   '봄',
#   '발라드',
#   '드라이브',
#   '여행',
#   '사랑',
#   '까페',
#   '비오는날',
#   '겨울',
#   '눈오는날',
#   '명품',
#   '잔잔한',
#   '새벽감성',
#   '발라드',
#   '노랫말을듣는다',
#   '감성발라드',
#   'ralalra',
#   '프러포즈',
#   '잔잔한',
#   '사랑',
#   '결혼',
#   '발라드',
#   '휴식',
#   '카페',
#   '발라드',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '신곡',
#   '데일리',
#   'Daily',
#   '데일리뮤직',
#   '감성',
#   '기분전환',
#   '새로운',
#   '신나는',
#   '휴식',
#   '기분전환',
#   '발라드',
#   '봄',
#   '주말',
#   '잔잔한',
#   '데이트',
#   '연애',
#   '사랑',
#   '고막폭행범',
#   '기분전환하기좋은',
#   '프리한19',
#   '나만의플레이리스트',
#   '감성충만',
#   '음색깡패',
#   '달달',
#   '사랑',
#   '좋아하는여자에게',
#   '짝사랑',
#   '남자가수짝사랑곡',
#   '성공적',
#   '연애',
#   '사랑노래',
#   '까페에서듣기좋은노래',
#   '힐링',
#   '커피마시면서',
#   '감성',
#   '매장음악',
#   '아침',
#   '카페',
#   '잔잔한',
#   '취향저격',
#   '출근',
#   '센치',
#   '기분전환',
#   '커피숍',
#   '휴식',
#   '카페',
#   '잔잔한',
#   '오후',
#   '분위기',
#   '가사',
#   '힐링',
#   '생각',
#   '어쿠스티한',
#   '감성발라드',
#   '출근길',
#   '매장음악',
#   '아침',
#   '카페',
#   '잔잔한',
#   '취향저격',
#   '센치',
#   '감성',
#   '기분전환',
#   '커피숍',
#   '드라이브',
#   '기분전환',
#   '발라드',
#   'foryou',
#   '발라드',
#   '잔잔한',
#   '연인',
#   '고백',
#   '인디',
#   '발라드',
#   '결혼식축가',
#   '축가',
#   '사랑',
#   '감성',
#   '밤',
#   '발라드',
#   '웅장',
#   '새벽',
#   '센치',
#   '슬픔',
#   '아련한',
#   '여행',
#   '감성',
#   '드라이브',
#   '발라드',
#   '개인적취향',
#   '잔잔한',
#   '잔잔한',
#   '힐링',
#   '휴식',
#   '발라드',
#   '감성',
#   '봄캐롤',
#   '카페',
#   '취향저격',
#   '오후',
#   '드라이브',
#   '봄날',
#   '귀르가즘',
#   '저녁',
#   '감성',
#   '밤',
#   '발라드',
#   '발라드곡',
#   '잔잔한',
#   '드라이브',
#   '밤새벽',
#   '조용한',
#   '사랑',
#   '새벽',
#   '감성',
#   '밤',
#   '분위기깡패',
#   '취향저격',
#   '봄캐롤',
#   '노을',
#   '저녁',
#   '센치',
#   '쌀쌀한',
#   '봄날',
#   '이별',
#   '감성',
#   '2010년대',
#   '가을',
#   '발라드',
#   '아재',
#   '휴식',
#   '운동',
#   '인기가요',
#   '추억',
#   '캠핑',
#   '2000s',
#   '갬성',
#   '신나는',
#   '설렘',
#   '사랑',
#   '미세먼지',
#   '고음',
#   '소름돋는',
#   '상쾌한',
#   '기분전환',
#   '띵곡만',
#   '내취향',
#   '국내가요',
#   '스트레스',
#   '노래방',
#   '드라이브',
#   '카페',
#   '산책',
#   '분위기를',
#   '집중',
#   '휴식',
#   '어쿠스틱',
#   '발라드',
#   '조용한',
#   '띵곡만',
#   '인디',
#   '봄',
#   '발라드',
#   '발라드감성',
#   '저녁',
#   '새벽감성',
#   '술한잔',
#   '잠안올때',
#   '잠들기전',
#   '저녁',
#   '노동요',
#   '밤',
#   '카페',
#   '취향저격',
#   '오후',
#   '드라이브',
#   '사랑',
#   '상큼',
#   '선선한',
#   '노래모음',
#   '요즘듣는노래',
#   '감성',
#   '기분전환',
#   '잔잔한',
#   '피크닉',
#   '느낌있는',
#   '로맨틱',
#   '봄바람',
#   '취향저격',
#   '달달한',
#   '봄날',
#   '가사',
#   '부드러운',
#   '따뜻한',
#   '이별',
#   '감성',
#   '권태기',
#   '헤어짐',
#   '발라드',
#   '발라드감성',
#   '감성',
#   '발라드',
#   '감성',
#   '듣기좋은',
#   '밤',
#   '혼자',
#   '잔잔한',
#   '슬픔',
#   '조용한',
#   '노래들',
#   '새벽에',
#   '밤에',
#   '평범',
#   '카페',
#   '달달한',
#   '설레임',
#   '드라이브',
#   '연애',
#   '기분전환',
#   '데이트',
#   '썸',
#   '사랑',
#   '선선한',
#   '겨울',
#   '감성',
#   '잔잔한',
#   '멜로',
#   '발라드',
#   '휴식',
#   '힐링',
#   '까페',
#   '연말',
#   '신곡',
#   '연말결산',
#   '발라드',
#   '숨은명곡',
#   '추천곡',
#   '감성',
#   '기분전환',
#   '2019',
#   '띵곡',
#   '추천',
#   '잔잔한',
#   '발라드',
#   '숨은명곡',
#   '이별',
#   '자장가',
#   '감성',
#   '발라드',
#   '러브',
#   '축가',
#   '띵곡들',
#   '고백송',
#   '고백',
#   '사랑',
#   '달달',
#   '결혼식축가',
#   '사랑',
#   '설렘',
#   '잔잔한',
#   '여름',
#   '저녁',
#   '카페',
#   '드라이브',
#   '오후',
#   '감성음악',
#   '여름노래',
#   '선선한',
#   '신부',
#   '이벤트',
#   '여행',
#   '고백',
#   '2020',
#   '사랑',
#   '프로포즈',
#   '신랑',
#   '결혼식',
#   '축가',
#   '비오는날',
#   '휴식',
#   '봄',
#   '발라드',
#   '봄비',
#   '분위기',
#   '띵곡들',
#   '어쿠스틱한',
#   '조용하고',
#   '인디',
#   '저녁',
#   '나만알고싶은',
#   '카페',
#   '지친하루',
#   '오후',
#   '드라이브',
#   '봄날',
#   '감성',
#   '애창곡',
#   '노래방',
#   '인기곡',
#   '히트곡',
#   '신나는',
#   '피크닉',
#   '감성',
#   '오후',
#   '드라이브',
#   '불금',
#   '센치',
#   '연애',
#   '저녁',
#   '가사',
#   '봄날',
#   '감성',
#   '밤',
#   '카페',
#   '오후',
#   '드라이브',
#   '저녁',
#   '휴식',
#   '울고싶을때',
#   '기분전환',
#   '선선한',
#   '저녁',
#   '밤',
#   '카페',
#   '매장',
#   '봄날',
#   '밤새벽',
#   '감성',
#   '사랑',
#   '이별',
#   '잔잔한',
#   '감성',
#   '밤',
#   '새벽',
#   '발라드',
#   '위로',
#   '힐링',
#   '기분전환',
#   '시대불문',
#   '장르불문',
#   '짬봉',
#   '내노래',
#   '잔잔한',
#   '기분전환',
#   '발라드',
#   '집중',
#   '노동요',
#   '카페',
#   '가을',
#   '달달',
#   '사랑',
#   '데이트',
#   '오후',
#   '힘내',
#   '선선한',
#   '자기전',
#   '새벽',
#   '잔잔',
#   '발라드',
#   '고음',
#   '슬픔',
#   '힐링',
#   '기분',
#   '이별'],
#  46: ['일렉'],
#  47: ['밤', '새벽'],
#  48: ['추천곡',
#   '현대카드',
#   '정태영',
#   '팝추천',
#   '음잘알',
#   '팝',
#   '감성일렉',
#   '내적댄스',
#   '소울',
#   '알앤비',
#   '몽환적인',
#   '분위기있는',
#   '감성',
#   '밤',
#   '최애곡',
#   '컨템포러리알앤비',
#   'NoahShebib',
#   '클라우드랩',
#   'Drake',
#   'dvsn',
#   'RoyWoods',
#   'MajidJordan',
#   'PARTYNEXTDOOR',
#   'OVO',
#   'BakaNotNice',
#   '웨하스구름',
#   'RnB',
#   'HipHop',
#   'OVOSound',
#   'PARTYNEXTDOOR',
#   'groove',
#   '소울',
#   '알앤비',
#   'RnB',
#   '클럽',
#   '기분전환',
#   '자메이카',
#   '일렉트로니카',
#   '댄스홀',
#   '레게',
#   'Dancehall'],
#  49: ['잔잔한', '추억', '회상'],
#  50: ['동요자장가',
#   '어린이집',
#   '태교',
#   '피아노',
#   '명품동요',
#   '동요모음',
#   '유치원',
#   '자장가',
#   '동요',
#   '감성동요',
#   '유치원동요',
#   '인기동요',
#   '누리과정',
#   '교과서동요',
#   '명품동요',
#   '차안에서',
#   '여름동요',
#   '동요',
#   '율동동요',
#   '전래동요',
#   '자장가',
#   '곰_세마리',
#   '잔잔한동요',
#   '유아동요',
#   '명품동요',
#   '아름다운동요',
#   '어쿠스틱동요',
#   '동요',
#   '감성동요',
#   '감성',
#   '휴양지',
#   '드라이브',
#   '도로',
#   '힐링',
#   '여름휴가',
#   '여름동요',
#   '동요',
#   '스트레스해소'],
#  51: ['기분전환', '드라이브', '가을'],
#  52: ['Hardrock', 'AOR'],
#  53: ['인디',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '나',
#   '슬픔',
#   '감성',
#   '분위기',
#   '슬프게',
#   '발라드',
#   '소울',
#   '알앤비',
#   '기분전환',
#   '매장음악',
#   '휴식',
#   '힐링',
#   '밤',
#   '새벽',
#   '1990년대',
#   '추억',
#   '스테디셀러',
#   '국내',
#   '사랑',
#   '이별',
#   '발라드',
#   '슬픔',
#   '이별',
#   '가을',
#   '드라이브음악',
#   '앙',
#   '잔잔한',
#   '감성',
#   '밤',
#   '새벽',
#   '발라드',
#   '사랑',
#   '네생각',
#   '슬픔',
#   '밤',
#   '이별',
#   '그리움',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '감성',
#   '봄',
#   '카페',
#   '새벽',
#   '설레임',
#   '벚꽃',
#   '커피',
#   '인디',
#   '김민',
#   '밤',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '감성',
#   '가을',
#   '잔잔한',
#   '스트레스',
#   '여행',
#   '드리이브',
#   '낙엽',
#   '드라이브곡',
#   '락',
#   '발라드',
#   '까페',
#   '잔잔한',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '드라이브',
#   '겨울',
#   '휴식',
#   '카페',
#   '가을',
#   '드라이브',
#   '감성',
#   '음악',
#   '자주',
#   '듣는',
#   '발라드',
#   '스트레스',
#   '잔잔한',
#   '인디',
#   '발라드',
#   '싸이월드',
#   '추억',
#   '띵곡',
#   '싸이월드BGM',
#   '발라드',
#   '인디',
#   '매장음악',
#   '운동',
#   '휴식',
#   '밤',
#   '슬픔',
#   '이별',
#   '힙합',
#   '랩',
#   '추억',
#   '가을',
#   '회상',
#   '띵곡',
#   '페이버릿',
#   '명곡',
#   '내적댄스유발',
#   '휴식',
#   '잔잔한',
#   '봄날',
#   '힐링',
#   '스트레스',
#   '인디',
#   '랩',
#   '힐링',
#   '발라드',
#   '음악',
#   '알앤비',
#   '인디',
#   '추억',
#   '기분전환',
#   '회상',
#   '감성',
#   '갬성',
#   '추천',
#   '휴식',
#   '아이돌',
#   '드라이브',
#   '추천곡',
#   '프듀',
#   'MXM',
#   '플레이리스트',
#   '임영민',
#   '힐링',
#   '여성보컬',
#   '역주행_했으면_하는노래',
#   '015B',
#   '레전드',
#   '명곡',
#   '작곡가',
#   '특집',
#   '정석원',
#   '힙합',
#   '랩',
#   '슬픔',
#   '서러움',
#   '눈물',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '슬픔',
#   '이별',
#   '인디',
#   '힙합',
#   '랩',
#   '발라드',
#   '힙합',
#   '랩',
#   '슬픔',
#   '이별',
#   '가을',
#   '밤',
#   '새벽',
#   '슬픔',
#   '미안함',
#   '이별',
#   '잘지내',
#   '발라드',
#   '여기까지라고',
#   '마음',
#   '기분전환',
#   '까페',
#   '슬픈노래',
#   '혼자있는밤',
#   '이별노래',
#   '그리움',
#   '우울함',
#   '극대화',
#   '이별',
#   '힙합',
#   '랩',
#   '힐링',
#   '위로',
#   '감성',
#   '가을',
#   '발라드',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '발라드',
#   '까페',
#   '언제들어도좋은노래',
#   '추천곡리스트',
#   '듣자노래',
#   '밤',
#   '새벽',
#   '잔잔한',
#   '겨울',
#   '밤',
#   '새벽',
#   '갬성충만',
#   '자기전',
#   '발라드',
#   '스트레스',
#   '기분전환',
#   '미세먼지',
#   '가을밤',
#   '밤',
#   '가을',
#   '새벽',
#   '우울',
#   '분위기',
#   '밤에듣기좋은노래',
#   '잠들기전',
#   '회상',
#   '드라이브',
#   '가창력',
#   '소름',
#   'kpop',
#   '새벽',
#   '고요한',
#   '생각',
#   '밤',
#   '자기전',
#   '비오는날',
#   '후회',
#   '감성힙합',
#   '눈물',
#   '발라드',
#   '우울',
#   '눈물나는',
#   '감성노래',
#   '슬픔',
#   '이별슬픔',
#   '매장음악',
#   '잔잔한',
#   '발라드',
#   '드라이브',
#   '설렘',
#   '사랑',
#   '밤',
#   '새벽',
#   '발라드',
#   '가라앉은',
#   '잔잔한',
#   '추억',
#   '회상',
#   '힙합',
#   '랩',
#   '잔잔한',
#   '발라드',
#   '발라드',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '발라드',
#   '발라드',
#   '힙합',
#   '랩',
#   '락',
#   '스트레스',
#   '기분전환',
#   '슬픔',
#   '이별',
#   '힐링',
#   '휴식',
#   '스트레스',
#   '미니홈피',
#   '추천',
#   '추억',
#   '노래방',
#   '회상',
#   '드라이브',
#   '추억',
#   '기분전환',
#   '회상',
#   '매장음악',
#   '까페',
#   '발라드',
#   '겨울',
#   '가을',
#   '카페',
#   '발라드',
#   '버스',
#   '드라이브',
#   '사랑',
#   '이별',
#   '인디',
#   '기분전환',
#   '잔잔한',
#   '잔잔한',
#   '평소에',
#   '여자노래방',
#   '노래방',
#   '잔잔한',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '싸이월드',
#   '추억',
#   '싸이월드BGM',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '락',
#   '힙합',
#   '랩',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '발라드',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '휴식',
#   '힐링',
#   '기분전환',
#   '걱정',
#   '휴식',
#   '기분전환',
#   '감성',
#   '회상',
#   '치유',
#   '추억',
#   '슬픔',
#   '기분전환',
#   '사랑',
#   '이별',
#   '헤어짐',
#   '새벽',
#   '회상',
#   '잊혀짐',
#   '추억',
#   '헤어진후에',
#   '아픔',
#   '헤어짐',
#   '이별',
#   '발라드',
#   '슬픔',
#   '분위기',
#   '아련',
#   '애틋한',
#   '듣자구나',
#   '이별후에듣는노래',
#   '이별',
#   '이별노래',
#   '비오는날',
#   '잔잔한',
#   '밤',
#   '카페',
#   '새벽',
#   '발라드',
#   '인디',
#   '비',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '발라드',
#   '발라드',
#   '휴식',
#   '힐링',
#   '밤',
#   '새벽',
#   '겨울',
#   '감성',
#   '후폭풍',
#   '사랑',
#   '상처',
#   '이별',
#   '헤어짐',
#   '매달림',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '발라드',
#   '팝',
#   '비오는날',
#   '슬픔',
#   '이별',
#   '발라드',
#   '발라드',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '내취향',
#   '기분전환',
#   '밤',
#   '락',
#   '드라이브',
#   '여행',
#   '감성',
#   '아련',
#   '눈물',
#   '잔잔',
#   '그리움',
#   '이별',
#   '겨울',
#   '계절',
#   '새벽',
#   '이건꼭들어야해',
#   '좋은노래',
#   '힐링',
#   '외로움',
#   'dj딘',
#   '발라드',
#   '힙합',
#   '랩',
#   '스트레스',
#   '기분전환',
#   '겨울',
#   '잔잔한',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '감성',
#   '감성을',
#   '카페',
#   '잔잔한',
#   '새벽',
#   '노래',
#   '힐링',
#   '기분전환',
#   '사랑',
#   'cafe',
#   '발라드',
#   '까페',
#   '발라드',
#   '7080',
#   '4060',
#   '회상',
#   '추억',
#   '명곡',
#   '가요베스트',
#   '국내',
#   'JAYJE',
#   '가요',
#   '90',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '가을',
#   '응원',
#   '힘내',
#   '힙합',
#   '슬픔',
#   '이별노래',
#   '힙합',
#   '랩',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '회사',
#   '혼자',
#   '산책',
#   '외로움',
#   '겨울감성',
#   '혼자',
#   '발라드',
#   '겨울밤',
#   '보고싶다',
#   '이별',
#   '헤어짐',
#   '추위',
#   '새벽',
#   '매장음악',
#   '까페',
#   '슬픔',
#   '드라이브',
#   '이별',
#   '퇴근',
#   '휴식',
#   '가을',
#   '가을비',
#   '여행',
#   '바다',
#   '이별',
#   '외로움',
#   '겨울',
#   '첫눈',
#   '눈오는날',
#   '잠못드는밤에',
#   '잠들기싫은밤에',
#   '슬픔',
#   '이별',
#   '설렘',
#   '사랑',
#   '감성',
#   '90년대생',
#   '취향저격',
#   '2000년대',
#   '첫사랑',
#   '싸이월드',
#   '추억팔이',
#   '싸이월드',
#   '추억',
#   '2000년대',
#   '가요',
#   '기분전환',
#   '드라이브',
#   '락',
#   '안대근',
#   '발라드',
#   '발라드',
#   '힐링',
#   '휴식',
#   '매장음악',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '비오는날',
#   '슬픔',
#   '이별',
#   '힐링',
#   '휴식',
#   '추억',
#   '회상',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '발라드',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '발라드',
#   '락',
#   '이별',
#   '추억',
#   '공감',
#   '사랑',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '슬픔',
#   '이별',
#   '설렘',
#   '사랑',
#   '기분전환',
#   '밤',
#   '가을',
#   '새벽',
#   '비오는날',
#   '비올때듣기좋은',
#   '비오는날듣기좋은',
#   '비내리는날',
#   '비오는날가요',
#   '슬픔',
#   '이별',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '하루',
#   '위로가필요할때',
#   '잔잔한',
#   '마무리',
#   '좋은노래',
#   '위로',
#   '조용한',
#   '숙면',
#   '소울',
#   '알앤비',
#   '발라드',
#   '비오는날',
#   '추억',
#   '회상',
#   '미니홈피',
#   '추억',
#   '비오는날',
#   '기분전환',
#   '밤',
#   '새벽',
#   '비오는날',
#   '소울',
#   '알앤비',
#   '슬픔',
#   '이별',
#   '잔잔한',
#   '잔잔한',
#   '감성',
#   '가을',
#   '쓸쓸한',
#   '기분전환',
#   '드라이브',
#   '카페',
#   '여행',
#   '추천',
#   '발라드',
#   '인디',
#   '알앤비',
#   '모아놓은곡',
#   '감성자극',
#   '우울한',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '추억회상',
#   '감성',
#   '밤',
#   '새벽',
#   '추억',
#   'bgm',
#   '싸이월드',
#   '친구',
#   '감성',
#   '눈물',
#   '잔잔한',
#   '추억',
#   '그리움',
#   '기분전환',
#   '회상',
#   '힐링',
#   '휴식',
#   '추억',
#   '회상',
#   '힐링',
#   '휴식',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '추천곡',
#   '힐링',
#   '기분전환',
#   '휴식',
#   '세븐틴',
#   '발라드',
#   '알앤비',
#   '국내RnB',
#   '추억',
#   'RNBSOUL',
#   '2000년대',
#   '감미로운',
#   '발라드',
#   '미니홈피',
#   '감성',
#   '90년대생',
#   '발라드',
#   'OST',
#   '2000년대',
#   '드라마ost',
#   '노래방',
#   '한국노래',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '겨울',
#   '추억',
#   '회상',
#   '외로울때',
#   '밤',
#   '잔잔한',
#   '새벽',
#   '그리움',
#   '기분전환',
#   '불면증',
#   '지금',
#   '드라이브',
#   '밤',
#   '새벽',
#   '감성',
#   '혼자',
#   '가을',
#   '발라드',
#   '노래방',
#   '분위기있는',
#   '알앤비',
#   'RnB',
#   'soul',
#   '국내알앤비',
#   '소울',
#   '발라드',
#   '바다',
#   '드라이브',
#   '미니홈피',
#   '파도',
#   '버즈',
#   '발라드',
#   '먼데이키즈',
#   '추억',
#   'bgm',
#   '남자노래',
#   '엠씨더맥스',
#   '여성보컬',
#   '발라드',
#   '비오는날',
#   '슬픔',
#   '이별',
#   '밤',
#   '까페',
#   '새벽',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '겨울',
#   '밤',
#   '새벽',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '발라드',
#   '락',
#   '감성적인',
#   '감각',
#   '나만듣고싶은노래',
#   '인디',
#   '배경음악',
#   '회상',
#   '추억',
#   'bgm',
#   '브금',
#   '싸이월드',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '힙합',
#   '랩',
#   '발라드',
#   '휴식',
#   '봄',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '머리가맑아지는',
#   '샤워',
#   '발렌타인',
#   '봄',
#   '아침',
#   '목욕',
#   '모닝콜',
#   '힐링',
#   '기분전환',
#   '집에서',
#   '락',
#   '겨울',
#   '그사람',
#   '눈오는날',
#   'Winter',
#   '라디오',
#   '첫눈',
#   '첫사랑',
#   '힙합',
#   '본토',
#   '갬성',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '추천곡',
#   '아이린',
#   '슬기',
#   '조이',
#   '웬디',
#   '인스타그램',
#   '레벨',
#   '예리',
#   '레드벨벳',
#   'redvelvet',
#   '숨겨진',
#   '명곡',
#   '발라드',
#   '여자보컬',
#   '노래방추천곡',
#   '목소리좋은노래',
#   '노래방가면무조건',
#   '노래잘하게보이는',
#   '잘부르는',
#   '여자노래',
#   '노래방',
#   '여자노래방',
#   '싸이월드',
#   '추억회상',
#   '추억',
#   'bgm',
#   '브금',
#   '백예린',
#   '알앤비',
#   '커버',
#   '재즈',
#   '플레이리스트',
#   '락',
#   '안대근',
#   '또듣게될꺼야',
#   '아이리버',
#   '한번들으면',
#   '중학교시절',
#   '추석',
#   '위안',
#   '회상',
#   '추억',
#   '설날',
#   '집',
#   '위로',
#   '노래방',
#   '센치한',
#   '우울한',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩'],
#  54: ['발라드', 'OST', '발라드', 'OST', 'OST', '발라드', '설렘', '사랑', '스트레스', '드라이브'],
#  55: ['차이코프스키', '차이콥스키', '피아노협주곡', '클래식명곡', '바이올린협주곡'],
#  56: ['뉴에이지'],
#  57: ['힐링',
#   '휴식',
#   '스트레스',
#   '감성음악',
#   '깊은밤',
#   '새벽',
#   '비오는날',
#   '감성',
#   '밤',
#   '새벽',
#   '취향저격',
#   '차분하게',
#   '목소리좋다',
#   '2030',
#   '감성',
#   '가을',
#   '새벽',
#   '우울',
#   '발라드',
#   '가요',
#   '사랑',
#   '이별',
#   '추억',
#   '회상',
#   '감성',
#   '밤',
#   '가을',
#   '새벽',
#   '발라드',
#   '센치한날',
#   '눈물',
#   '사랑',
#   '이별',
#   '앙',
#   '잔잔한',
#   '감성',
#   '밤',
#   '새벽',
#   '발라드',
#   '사랑',
#   '샤이니발라드',
#   '샤이니',
#   '아이돌수록곡',
#   '아이돌숨은명곡',
#   '발라드',
#   'SHINee',
#   '아이돌발라드',
#   '발라드명곡',
#   '비오는날',
#   '기분전환',
#   '드라이브',
#   '설렘',
#   '사랑',
#   '슬픔',
#   '울고싶은날',
#   '이별',
#   '눈물',
#   '우울',
#   '김종현',
#   '종현',
#   '샤이니',
#   '샤이니종현',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '노래추천',
#   '발라드모음',
#   '아이돌',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '노래',
#   '공연',
#   '콘서트',
#   '이별곡',
#   '감성',
#   '이별',
#   '눈물',
#   '소울',
#   '알앤비',
#   '먹먹',
#   '쓸쓸',
#   '장마',
#   '비',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '슬픔',
#   '이별',
#   '까페',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '정말고생했어요',
#   '수고했어요',
#   '스트레스',
#   '기분전환',
#   '멋지다',
#   '즐기다',
#   '남자아이돌',
#   '뿜뿜',
#   '하트',
#   '댄스댄스',
#   '설렘',
#   '빠져든다',
#   '따라잡기',
#   '스트레스',
#   '밤',
#   '새벽',
#   '스트레스',
#   '랜덤재생',
#   'SM',
#   '장르불문',
#   '슬픔',
#   '이별',
#   '댄스',
#   '슬픔',
#   '이별',
#   '설렘',
#   '사랑',
#   '슬픈노래',
#   '이별',
#   '감성',
#   '새벽',
#   '감성',
#   '잔잔한',
#   '분위기',
#   '부드러운',
#   '자장가',
#   '따뜻한',
#   '비오는날',
#   '가을',
#   '겨울',
#   '잔잔한',
#   '잠못드는밤',
#   '잠들기전에듣는노래',
#   '스트레스',
#   '드라이브',
#   '취향주의',
#   '기분전환',
#   '기분전환',
#   '매장음악',
#   '발라드',
#   '발라드',
#   '힐링',
#   '휴식',
#   '설렘',
#   '사랑',
#   '비오는날',
#   '기분전환',
#   '비오는날',
#   '감성',
#   '발라드',
#   '우울',
#   '가을비',
#   '그리움',
#   '생각',
#   '이별',
#   '센치한',
#   '야경',
#   '발라드',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '비오는날',
#   '감성',
#   '취향저격',
#   '그리움',
#   '슬픔',
#   '떠나지마',
#   '첫사랑',
#   '2030',
#   '첫이별',
#   '이별',
#   '잔잔한',
#   '추억',
#   '회상',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '종현',
#   '태민',
#   '샤이니',
#   'SM',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '추억',
#   '운동',
#   '회상',
#   '운동',
#   '설렘',
#   '사랑',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '아이돌의숨은명곡',
#   '애잔한',
#   '댄스',
#   '힐링',
#   '휴식',
#   '설렘',
#   '사랑',
#   '경만',
#   '저장용',
#   '아이돌그룹',
#   '잠깰때',
#   '드라마',
#   '공부',
#   '도서관',
#   '슬픔',
#   '밤',
#   '이별',
#   '눈물',
#   '새벽',
#   '팝',
#   '절절한',
#   '명곡',
#   '혼자',
#   '발라드',
#   '추억회상',
#   '샤이니',
#   '종현',
#   '싱어송라이터',
#   '남자보컬',
#   '그리움',
#   '슬픔',
#   '발라드',
#   '기분전환',
#   '종현',
#   '슬픔',
#   '샤이니',
#   '그리움',
#   '감성',
#   '비',
#   '발라드',
#   '이별후',
#   '생각',
#   '그리움',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '종현',
#   '새벽',
#   '밤',
#   '잔잔한',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '힐링',
#   '휴식',
#   '추억',
#   '회상',
#   '샤이니발라드',
#   '샤이니',
#   '아이돌수록곡',
#   '발라드',
#   'SHINee',
#   '아이돌발라드',
#   '발라드명곡',
#   '종현',
#   '샤이니',
#   '고생했어',
#   '종현아',
#   '비'],
#  58: ['감성자극',
#   '겨울밤',
#   '새벽',
#   '센치',
#   '혼자있을때',
#   '밤에듣기좋은노래',
#   '늦은밤',
#   '침대',
#   '자장가',
#   '편안한',
#   '여유로운',
#   '겨울',
#   '감성',
#   '아침',
#   '잔잔한',
#   '출근길',
#   '기분전환',
#   '일상',
#   '추위',
#   '힐링',
#   '출근길',
#   '감성',
#   '여유',
#   '아침',
#   '위로',
#   '힐링',
#   '기분전환',
#   '스트레스',
#   '겨울',
#   '감성',
#   '밤',
#   '연주곡',
#   '잔잔한',
#   '피아노',
#   '센치',
#   '추위',
#   '자장가',
#   '쌀쌀한'],
#  59: ['미세먼지', '포근함', '보사노바', '취향저격DJ', 'J_보사', '일본', '따스한', '기분전환'],
#  60: ['새벽',
#   '추억',
#   '밤',
#   '회상',
#   '여기까지라고',
#   '마음',
#   '신혜성',
#   '전진',
#   '김동완',
#   '이민우',
#   '신화',
#   '신화창조',
#   '앤디',
#   '에릭',
#   '12월',
#   '겨울',
#   '겨울노래',
#   '크리스마스',
#   '발라드',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '힐링',
#   '휴식',
#   '겨울'],
#  61: ['소울',
#   '알앤비',
#   '소울',
#   '알앤비',
#   '봄',
#   '까페',
#   '숨은명곡',
#   'RnB',
#   '달달',
#   '드라이브',
#   '그루브',
#   '설렘',
#   '알엔비',
#   '띵곡',
#   '인디',
#   '설렘',
#   '까페',
#   '사랑',
#   '겨울',
#   '까페',
#   '발라드',
#   '매장음악',
#   '가을',
#   'pop모집',
#   '가벼운',
#   '듣기좋은',
#   '가볍게',
#   '분위기전환',
#   '드라이브',
#   'Pop',
#   '기분전환',
#   '팝송',
#   '팝',
#   '재즈힙합',
#   'SamOck',
#   '샘옥',
#   '겨울',
#   '까페',
#   '소울',
#   '알앤비',
#   '소울',
#   '알앤비',
#   '겨울',
#   '까페',
#   '내가좋아하는노래',
#   '너도좋아할걸',
#   '잘될거야',
#   '응원',
#   '활기찬',
#   '시작',
#   '새학기',
#   '기분전환',
#   '밝은',
#   '스트레스',
#   '화이팅',
#   '신나는',
#   '팝',
#   '소울',
#   '알앤비',
#   '힐링',
#   '휴식',
#   '까페',
#   '힙합',
#   '랩',
#   '겨울',
#   '설렘',
#   '사랑',
#   '봄',
#   '분위기있는',
#   '해외팝',
#   '감성',
#   '느낌있는',
#   '감성',
#   '봄',
#   '연인',
#   '드라이브',
#   '사랑',
#   '리드미컬',
#   '발라드',
#   '하루',
#   '휴식',
#   '아침',
#   '여유롭게',
#   '출근길',
#   '기분전환',
#   '소울',
#   '알앤비',
#   '힙합',
#   '야경',
#   '랩',
#   '감각적인',
#   '분위기',
#   '사랑',
#   '잔잔',
#   '위로',
#   '밤산책',
#   '힐링',
#   '휴식',
#   '기분전환',
#   'HipHop',
#   'Jazz',
#   'Rap',
#   '감성',
#   '가을',
#   '발라드',
#   '새벽감성',
#   'RnB',
#   '연인',
#   '추억',
#   '사랑',
#   '분위기',
#   '일렉',
#   '락',
#   '기분전환',
#   '까페',
#   '없다',
#   '까페',
#   '잔잔한',
#   '비오는날',
#   '우울한날',
#   '팝발라드',
#   '팝',
#   '가을',
#   '까페',
#   '기타',
#   '분위기',
#   '팝',
#   '가을',
#   'Pop',
#   '팝',
#   '팝송',
#   '드라이브할때듣는팝',
#   '팝',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '소울',
#   '알앤비',
#   '겨울',
#   '까페',
#   '여유',
#   '밤',
#   '가을',
#   '새벽',
#   '힐링',
#   '휴식',
#   '까페',
#   '추억',
#   '가을',
#   '회상',
#   '힙합',
#   '랩',
#   '기분전환',
#   '비오는날',
#   '카페에서',
#   '팝발라드',
#   '팝',
#   '매장음악',
#   '까페',
#   '기분전환',
#   '까페',
#   '감성',
#   '가을',
#   '이런날엔이런음악',
#   '선선한날',
#   '팝',
#   '감성팝',
#   '슬픔',
#   '이별',
#   '설렘',
#   '사랑',
#   '추천',
#   '휴식',
#   '아이돌',
#   '드라이브',
#   '추천곡',
#   '프듀',
#   'MXM',
#   '플레이리스트',
#   '임영민',
#   '힐링',
#   '팝',
#   '하루',
#   '흐린날',
#   '감수성',
#   '폭발',
#   '감성팝',
#   '따뜻한',
#   '매력적인',
#   '팝',
#   '일렉',
#   '비오는날',
#   '감성',
#   '느낌있는',
#   '해외',
#   '알앤비',
#   '새벽',
#   '알엔비',
#   '팝',
#   '알앤비소울',
#   '소울',
#   'CCM',
#   '해외CCM',
#   'CCM맞아',
#   'bestccm',
#   'CCM같지않은CCM',
#   '소울',
#   '알앤비',
#   '겨울',
#   '휴식',
#   '잔잔한',
#   '겨울밤',
#   '기분전환',
#   '팝',
#   '여행',
#   '산책',
#   '공부',
#   '팝',
#   '힐링',
#   '휴식',
#   '봄',
#   '여름',
#   '까페',
#   '시원한설렘',
#   '여름',
#   '사이공스퀘어',
#   '감성',
#   '힐링',
#   '휴식',
#   '까페',
#   '커피',
#   '팝',
#   '카페',
#   '소울',
#   '알앤비',
#   '소울',
#   '알앤비',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '까페',
#   '설렘',
#   '사랑',
#   '봄',
#   '재충전',
#   '응원',
#   '시작',
#   '출발',
#   '에너지',
#   '기분전환',
#   '붐업',
#   '2020',
#   '새로운',
#   '신나는',
#   '팝',
#   '팝',
#   '인디',
#   '힐링',
#   '휴식',
#   '드라이브',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '휴식',
#   '힐링',
#   '밤',
#   '새벽',
#   '휴식',
#   '달달한',
#   '드라이브',
#   '여행',
#   '힐링',
#   '기분전환',
#   '사랑',
#   '중독',
#   '스트레스',
#   '산뜻한',
#   '저녁',
#   '해질녘',
#   '목소리',
#   '달달',
#   '훈남',
#   '힐링',
#   '팝',
#   '라이딩',
#   '소울',
#   '알앤비',
#   '비오는날',
#   '까페',
#   '고막남친',
#   '따듯한',
#   '감성',
#   '어쿠스틱',
#   '여행',
#   '팝송',
#   '신나는',
#   '기분전환',
#   '까페',
#   '가을',
#   '까페',
#   '추억',
#   '기분전환',
#   '회상',
#   '소울',
#   '알앤비',
#   '팝',
#   '들어봐요',
#   '팝',
#   '추억',
#   '기분전환',
#   '회상',
#   '매장음악',
#   '까페',
#   '스트레스',
#   '기분전환',
#   '소울',
#   '알앤비',
#   '팝',
#   '기분전환',
#   '신나는',
#   '봄',
#   '설렘',
#   '사랑',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '추억',
#   '기분전환',
#   '회상',
#   '카페음악',
#   '카페',
#   '잔잔한',
#   '재즈',
#   '모든장르',
#   '팝',
#   '까페',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '기분전환',
#   '카페',
#   '여행',
#   '기분전환',
#   '산책',
#   '여름',
#   '기분전환',
#   '힙합',
#   '랩',
#   '봄',
#   '설렘',
#   '사랑',
#   '까페',
#   '잔잔한',
#   '감성',
#   'Pop',
#   '그루브',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '비오는날',
#   '까페',
#   '출근길',
#   '기분전환',
#   '아침',
#   '무드',
#   '봄',
#   '잔잔',
#   '겨울',
#   '집',
#   '따듯',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '소울',
#   '알앤비',
#   '여름',
#   '까페',
#   '드라이브',
#   '그루브',
#   '매장음악',
#   '까페',
#   '휴식',
#   '힐링',
#   '까페',
#   '까페',
#   '잔잔한',
#   '휴식',
#   '힐링',
#   '밤',
#   '새벽',
#   '겨울',
#   '봄',
#   '겨울밤',
#   '사랑해',
#   '감각적인',
#   '불금',
#   '썸',
#   '퇴근길',
#   '휴가',
#   '힐링',
#   '휴식',
#   '까페',
#   '소울',
#   '알앤비',
#   '카페음악',
#   '매장음악',
#   '기분좋은',
#   '흥얼흥얼',
#   'Pop',
#   '그루브',
#   '팝',
#   '소울',
#   '알앤비',
#   '여름',
#   '밤',
#   '새벽',
#   '휴식',
#   '잔잔한',
#   '취향저격',
#   '명곡',
#   'Pop',
#   '힐링',
#   '기분전환',
#   '팝송',
#   '감성적인',
#   '스트레스',
#   'cafe',
#   '까페',
#   '카페',
#   'Pop',
#   '독서',
#   '힐링',
#   '수다',
#   '노가리',
#   '까페',
#   '기분전환',
#   '가을',
#   '힐링',
#   '휴식',
#   '설렘',
#   '사랑',
#   '힙합',
#   '랩',
#   '기분전환',
#   '휴식',
#   '드라이브',
#   '인디',
#   '가을감성',
#   '소울',
#   '알앤비',
#   '팝송',
#   '크리스마스',
#   '캐롤',
#   '조용히',
#   '스트레스',
#   '드라이브',
#   '시간',
#   '사색',
#   '커피',
#   '위한',
#   '나를',
#   '스피커',
#   '내공간',
#   '감성',
#   '아름다운',
#   '알앤비',
#   '연주',
#   '슬픈',
#   '팝',
#   '여행',
#   '산책',
#   '밤',
#   '새벽',
#   '일렉',
#   '밤에운전',
#   '밤에드라이브',
#   '감성',
#   '듣기좋은',
#   '밤',
#   '차타고',
#   '드라이브',
#   '다리건널때',
#   '운전하면서',
#   '밤에',
#   '까페',
#   '잔잔한',
#   '비오는날',
#   '감성',
#   '봄',
#   '봄비',
#   '불금',
#   '힐링',
#   '빗소리',
#   '집에서',
#   '데이트',
#   '차한잔',
#   '트렌디',
#   '팝',
#   '카페',
#   '새벽',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '매장음악',
#   '까페',
#   '재즈힙합',
#   '좋은음악',
#   '기분전환',
#   '락',
#   '소울',
#   '알앤비',
#   '힙합',
#   '랩',
#   '겨울',
#   '까페',
#   '스트레스',
#   '기분전환',
#   '소울',
#   '알앤비',
#   '힐링',
#   '휴식',
#   '잔잔한',
#   '기분전환',
#   '까페',
#   '감성',
#   '카페',
#   '드라이브',
#   '그루브',
#   '기분전환',
#   '띵곡',
#   '소울',
#   '소울',
#   '알앤비',
#   '팝',
#   '여행',
#   '사랑',
#   '설렘',
#   '산책',
#   '밤',
#   '까페',
#   '새벽',
#   'CCM',
#   '매장음악',
#   '기분전환',
#   '기분전환',
#   '까페',
#   '퇴근',
#   '휴식',
#   '기분',
#   '지침',
#   '피크닉',
#   '힐링',
#   '기분전환',
#   '전환',
#   '외로움',
#   '스트레스',
#   '기분전환',
#   '봄',
#   '팝송',
#   '힐링',
#   '휴식',
#   '드라이브',
#   '휴식',
#   '가을',
#   '카페',
#   '힐링',
#   '기분전환',
#   '감성팝',
#   '집중',
#   '비오는날',
#   '무드',
#   '애잔한',
#   '발라드',
#   '감성',
#   '소울',
#   '알앤비',
#   '까페',
#   '팝',
#   '감성',
#   '카페',
#   '스트레스',
#   '드라이브',
#   '좋은노래',
#   'Pop',
#   '여행',
#   '기분전환',
#   '산책',
#   '팝',
#   '발라드',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '목소리깡패',
#   '카페',
#   '귀르가즘',
#   '달달',
#   '음색',
#   '꿀성대',
#   '팝송',
#   '멜로디',
#   '감미로운',
#   '귀호강',
#   '여름',
#   '여행',
#   '산책',
#   '힐링',
#   '휴식',
#   '봄',
#   '겨울',
#   '까페',
#   '힐링',
#   '휴식',
#   '기분전환',
#   'kpop',
#   '휴식',
#   '미디움템포',
#   '분위기',
#   'Pop',
#   '도시적인',
#   '사랑',
#   '음악감상',
#   '음악추천',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '휴식',
#   '힐링',
#   '드라이브',
#   '소울',
#   '알앤비',
#   '기분전환',
#   '매장음악',
#   '매장음악',
#   '까페',
#   '드라이브',
#   '까페',
#   '매장음악',
#   '까페',
#   'CCM',
#   '팝송추천',
#   '비오는날',
#   '까페',
#   '감성',
#   '카페',
#   'Relax',
#   '매장',
#   '드라이브',
#   'Pop',
#   '여행',
#   '퇴근길',
#   'cafe',
#   '팝',
#   '발라드',
#   '고막남친',
#   '주말',
#   '아침',
#   '사랑',
#   '즐거운',
#   '봄캐롤',
#   '설렘',
#   '데이트',
#   '산뜻한',
#   '포근한',
#   '매장음악',
#   '설렘',
#   '사랑',
#   'jazzygroovy',
#   'HipHop',
#   '클래식',
#   '인디',
#   '발라드',
#   '매장음악',
#   '까페',
#   '팝',
#   '팝',
#   '힐링',
#   '휴식',
#   '설렘',
#   '사랑',
#   '까페',
#   '설렘',
#   '사랑',
#   '사랑',
#   '밤',
#   '설렘',
#   '새벽',
#   'OST',
#   '힐링',
#   '휴식',
#   '까페',
#   '잠언집',
#   '지침서',
#   'Pop',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '소울',
#   '알앤비',
#   '잔잔한',
#   '설렘',
#   '사랑',
#   '힙합',
#   '감성',
#   '알앤비',
#   '까페',
#   '잔잔한',
#   '팝',
#   '기분전환',
#   'CCM',
#   '기분전환',
#   '밤',
#   '새벽',
#   '힐링',
#   '휴식',
#   '봄',
#   '집중',
#   '밤',
#   '잔잔한',
#   'RnB',
#   '포크',
#   '새벽',
#   '히든트랙',
#   '인디',
#   '가을',
#   '까페',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '슬픔',
#   '밤',
#   '이별',
#   '새벽',
#   '까페',
#   '힙합',
#   '랩',
#   '이별까지',
#   '개성있는_인디음악으로만',
#   '연애하고',
#   '혼자_썸타고',
#   '기분전환',
#   '까페',
#   'Pop',
#   '소울',
#   '알앤비',
#   '소울',
#   '알앤비',
#   '재즈힙합',
#   '힐링',
#   '카페',
#   '기분전환',
#   '팝',
#   '잔잔한음악',
#   '카페음악',
#   '카페',
#   '잔잔',
#   '카페에서',
#   '카페테라스',
#   '감성pop',
#   '분위기있는',
#   '감성',
#   '느낌있는',
#   '밤',
#   '드라이브',
#   '그루브',
#   '노랫말을듣는다',
#   'ralalra',
#   '알앤비소울',
#   '소울',
#   '알앤비',
#   '발라드',
#   '기분전환',
#   '가을',
#   '매장음악',
#   '기분전환',
#   '봄',
#   '설렘',
#   '사랑',
#   '소울',
#   '알앤비',
#   '매장음악',
#   '까페',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '여행',
#   '기분전환',
#   '산책',
#   '소중한노래들',
#   '잔잔한',
#   '드라이브',
#   '기분전환',
#   '소울스타',
#   '어쿠루브',
#   '흥',
#   '일렉트로니카',
#   '매장음악',
#   '드라이브',
#   '신나는',
#   '겨울',
#   '감성',
#   '밤',
#   '카페',
#   '잔잔한',
#   '새벽',
#   '위로',
#   '힐링',
#   '따뜻한',
#   '매장음악',
#   '가을',
#   '자존감',
#   '위로',
#   '휴식',
#   '청춘',
#   '회상',
#   '여행',
#   '드라이브',
#   '산책',
#   '일렉',
#   '잠',
#   '겨울',
#   '감성',
#   '새벽',
#   '달달',
#   '리듬감',
#   '사랑',
#   'CCM',
#   '매장음악',
#   '스트레스',
#   '드라이브',
#   '락',
#   '봄',
#   '까페',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '팝',
#   '까페',
#   '댄스',
#   '감성',
#   '버스',
#   '집',
#   '위로',
#   '힐링',
#   '팝송',
#   '기분전환',
#   '퇴근길',
#   '스트레스',
#   '다짐',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '락',
#   '여행',
#   '봄',
#   '산책',
#   '잔잔한음악',
#   '팝송',
#   '힐링',
#   '휴식',
#   '잔잔한',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '잔잔한',
#   '설렘',
#   '사랑',
#   '굿모닝멜론',
#   '기상후',
#   '아침',
#   '생체리듬',
#   '잔잔한',
#   '매장음악',
#   '카페',
#   '잔잔한',
#   '달달',
#   '분위기',
#   '커피',
#   '부드러운',
#   '여름',
#   '까페',
#   '집중',
#   '노동요',
#   '아침',
#   '월요병',
#   '매장',
#   '엔돌핀',
#   '작업',
#   '사무실',
#   '메이크업샵',
#   '오후',
#   '봄',
#   '까페',
#   '힙합',
#   '랩',
#   '감성적인음악',
#   '음악에취해',
#   '달달한',
#   '취향저격',
#   '이어폰끼고',
#   '잔잔한',
#   '새벽감성',
#   '힐링',
#   '새벽',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '휴식',
#   '힐링',
#   '봄',
#   '카페',
#   '산책',
#   '기분좋은',
#   '출근길',
#   '하교길',
#   '등교길',
#   '신난다',
#   '퇴근길',
#   '좌절금지',
#   '밤',
#   '새벽',
#   '우울',
#   '20대후반',
#   '위로',
#   '불안',
#   '불면증',
#   '청춘',
#   '기분전환',
#   '매장음악',
#   '달달',
#   '설렘',
#   '사랑',
#   '기분전환',
#   '까페',
#   '팝',
#   '알앤비',
#   '야경',
#   '드라이브',
#   '도시',
#   '맥주',
#   '불금',
#   '힐링',
#   '팝송',
#   '기분전환',
#   '새벽',
#   '소울',
#   '알앤비',
#   '힐링',
#   '휴식',
#   '추억',
#   '회상',
#   '소울',
#   '알앤비',
#   '소울',
#   '알앤비',
#   '드라이브',
#   '느낌있어',
#   '카페',
#   '잔잔한',
#   '청개구리DJ',
#   '기분전환',
#   '봄',
#   'Pop',
#   '추천',
#   '휴식',
#   '감성자극',
#   '카페',
#   '새벽',
#   '촉촉한',
#   '센치',
#   '감성',
#   '재즈힙합',
#   '침대',
#   '힙합',
#   '영민시뮤직',
#   'MXM',
#   '임영민',
#   '잔잔한',
#   '겨울',
#   '까페',
#   'HipHop',
#   'Jazz',
#   '락',
#   '여행',
#   '사랑',
#   '설렘',
#   ...],
#  62: ['힙합', '흑인음악', 'GOLFWANG', '힙합엘이', 'OFWGKTA', 'HipHop', '외힙', '오드퓨처'],
#  63: ['재즈'],
#  64: ['락', '메탈'],
#  65: ['매장음악', '알앤비', 'RnB', '감각적인', '그루브', '힙스터', '느낌있는', '섹시한', '트렌디', '소울'],
#  66: ['CCM', '파워DJ_CCM', '해외CCM', '연말결산', '총정리'],
#  67: ['배경음악',
#   '꽃보다청춘',
#   '휴식',
#   'bgm',
#   '여행',
#   '힐링',
#   '삽입곡',
#   '삼시세끼',
#   '뉴에이지',
#   '여행',
#   '산책',
#   '잔잔한',
#   '휴식',
#   '힐링',
#   '여행',
#   '산책',
#   '클래식'],
#  68: ['1990',
#   '차트',
#   '회상',
#   '인기순위',
#   '추억',
#   '명곡',
#   'Pop',
#   '빌보드',
#   '팝',
#   '팝',
#   '가을',
#   '설렘',
#   '사랑',
#   '기분전환',
#   '까페',
#   '팝',
#   '락'],
#  69: ['스트레스', '매장음악', '국내가요모음'],
#  70: ['JPOP',
#   '매력있는',
#   '재즈',
#   '재즈음악',
#   '재즈보컬',
#   '재즈피아노',
#   '재즈보컬리스트',
#   'JPOP',
#   '마들렌느페이루',
#   '다이애나크롤',
#   '로라피지',
#   '니키야노프스키',
#   '보컬리스트',
#   '재즈',
#   '여성',
#   '노라존스',
#   '멜로디가르도트',
#   '일렉',
#   'JPOP',
#   'JPOP'],
#  71: ['SOMOS',
#   '게임할때',
#   'bgm',
#   '힙합',
#   '플스',
#   '롤',
#   '댄스',
#   '게임',
#   'LOL',
#   'EDM',
#   'pc방',
#   '설날',
#   '리그'],
#  72: ['다양한'],
#  73: ['락', '힐링', '휴식', '잔잔한'],
#  74: ['뉴에이지', '뉴에이지'],
#  75: ['드라이브할때',
#   '어번한',
#   '감각적인',
#   '가을을_위한_플레이리스트',
#   '산책할때',
#   '감성적인',
#   '혼자서도_듣기좋은',
#   '도회적인'],
#  76: ['리듬', '베이스', '비틀즈', '코즈니'],
#  77: ['최신일렉트로닉', '트렌디', '나만알고싶은', '트렌디이디엠', '최신이디엠'],
#  78: ['클럽',
#   '홍대',
#   'dance',
#   'EDM',
#   '불금',
#   '이태원',
#   '강남',
#   'Electronic',
#   '할로윈',
#   '클럽',
#   'TurnUp',
#   '댄스',
#   'EDM',
#   'dance',
#   '불금',
#   'Club',
#   '파티',
#   'Electronic',
#   'Beat'],
#  79: ['OST',
#   'OST',
#   '발라드',
#   '발라드',
#   '힐링',
#   '휴식',
#   '설렘',
#   '사랑',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '발라드',
#   '발라드',
#   '겨울',
#   '락',
#   '멜랑꼴리',
#   '우울',
#   '위로가필요할때',
#   '헤어짐',
#   '퇴폐',
#   '휴식',
#   '가을',
#   '노을',
#   '발라드',
#   '아이유',
#   '김광석',
#   '발라드',
#   '겨울',
#   '밤',
#   '새벽',
#   'OST',
#   '발라드',
#   'OST',
#   '밤',
#   '해외',
#   '새벽',
#   'movie',
#   'OST',
#   'Soundtrack',
#   '영화',
#   '영화OST',
#   '외국영화',
#   '영화음악',
#   '배우',
#   'OST',
#   'Drama',
#   '드라마',
#   '드라마ost',
#   'ballad',
#   '발라드',
#   '발라드',
#   '발라드',
#   'OST',
#   'OST',
#   '발라드'],
#  80: ['RnB',
#   'HipHop',
#   'soul',
#   '감성',
#   '카페',
#   '잔잔한',
#   '잠들기전',
#   '기분전환',
#   '불면증',
#   '숙면',
#   '인디',
#   '외로움',
#   'PBRnB',
#   'soul',
#   'RnB',
#   '힙합',
#   '선곡은',
#   '인듯',
#   '쫀쫀한리듬',
#   '내가할게',
#   '끈적한그루브',
#   '그냥들어',
#   '귀를',
#   '일렉',
#   '카페음악',
#   '알앤비',
#   '드라이브',
#   'Pop',
#   '팝',
#   '감성팝',
#   '스트레스',
#   '기분전환',
#   '하루',
#   '감성',
#   '밤',
#   '자기전',
#   '알앤비',
#   '음색',
#   '휴식',
#   '해외알앤비소울',
#   '힐링',
#   '지친',
#   '정박',
#   '분위기',
#   '알앤비',
#   '드라이브',
#   'RNBSOUL',
#   'soul',
#   '알앤비추천',
#   '알앤비힙합',
#   '노래추천',
#   'RnB',
#   '알앤비소울',
#   '소울',
#   '비트감',
#   '저녁',
#   '몽환',
#   '그루브',
#   '하교길',
#   '흔들흔들',
#   '퇴근길',
#   '스트레스',
#   '카페',
#   '버스',
#   '분위기',
#   '드라이브',
#   'Pop',
#   '흔하지않은',
#   '작업',
#   '퇴근길',
#   '팝',
#   '오후',
#   '휴식',
#   '매장음악',
#   '밤',
#   '잔잔한',
#   'RnB',
#   '새벽',
#   'soul',
#   '알앤비',
#   '감성',
#   '소울',
#   '비오는날',
#   '감성',
#   '느낌있는',
#   '해외',
#   '알앤비',
#   '새벽',
#   '알엔비',
#   '팝',
#   '알앤비소울',
#   '소울',
#   '야경',
#   '밤',
#   '매장',
#   '드라이브',
#   '그루브',
#   '리드미컬',
#   '퇴근길',
#   '팝',
#   '편집샵',
#   '잠못드는밤',
#   '새벽녘',
#   'RB',
#   '휴식',
#   '주말',
#   '잔잔한',
#   '오후',
#   '나른한',
#   '힐링',
#   '리듬',
#   '잔잔한',
#   '매장음악',
#   '노래',
#   '그루브',
#   '카페음악',
#   '라운지',
#   '혼술',
#   '알앤비',
#   '감성',
#   '기분전환',
#   'Pop',
#   '그루브',
#   '소울',
#   '알앤비',
#   '잔잔한',
#   '휴식',
#   '밤',
#   '혼자',
#   '새벽',
#   '분위기',
#   '센치',
#   '감성',
#   '트렌디',
#   '세련된',
#   '여름',
#   '감성',
#   '봄',
#   '가을',
#   '잔잔한',
#   '새벽',
#   '드라이브',
#   '알앤비',
#   '커피숍',
#   '밤',
#   'Pop',
#   '좋아요',
#   '기분전환',
#   '느낌적인',
#   '드라이브',
#   'Pop',
#   '전체재생추천',
#   '휴식',
#   '겨울감성',
#   '카페',
#   '겨울밤',
#   '눈',
#   'RnB',
#   '다양한장르',
#   '잔잔',
#   '감성',
#   'soul',
#   '새벽',
#   '힙합',
#   '감성',
#   '알앤비',
#   '새벽감성',
#   '새벽',
#   '드라이브',
#   '도시',
#   '감성',
#   '매장',
#   '몽글몽글',
#   '무드',
#   '분위기',
#   '패션',
#   '휴식',
#   '카페',
#   '새벽',
#   '매장',
#   '펍',
#   'Pop',
#   '라운지',
#   '트렌디',
#   '세련된',
#   '휴식',
#   '힐링',
#   '기분전환',
#   '까페',
#   '카페',
#   '비오는날',
#   '감성',
#   '매장음악',
#   '감각적인',
#   '기분전환',
#   '드라이브',
#   '패션',
#   '휴식',
#   '새벽',
#   '감각적인',
#   '매장',
#   '알앤비',
#   '라운지',
#   '트렌디',
#   '힐링',
#   '세련된',
#   '편집샵',
#   '카페',
#   '몽환적',
#   '한강',
#   '밤',
#   '드라이브',
#   'drive',
#   'JAYJE',
#   '드라이빙뮤직',
#   '힙합',
#   '밤',
#   '알앤비',
#   '팝',
#   '분위기',
#   '그루브',
#   '기분전환',
#   '혼술',
#   'groove',
#   'chilly',
#   'deepmood',
#   '감성',
#   '휴식',
#   '기분전환',
#   '비트',
#   '잔잔한',
#   '힙합',
#   '감성',
#   '알앤비',
#   'Drake',
#   'HipHop',
#   'OVOSound',
#   '디비젼',
#   '얼터너티브',
#   '소울',
#   '힙합',
#   '일렉트로니카',
#   '새벽',
#   '리듬',
#   '드라이브',
#   '그루브',
#   'R',
#   '소울',
#   '바이브',
#   '느낌',
#   '힙합',
#   '감성',
#   '밤',
#   '새벽',
#   '우울',
#   '분위기',
#   '알앤비',
#   '기분전환',
#   '팝',
#   '소울',
#   '알앤비',
#   '외국',
#   '외국힙합',
#   '비트',
#   '사운드',
#   '팝',
#   '얼터너티브',
#   'RnB',
#   'PBRnB',
#   'Night',
#   '드라이브',
#   'Sexy',
#   '감성',
#   'groove',
#   '그루브',
#   'PBRnB',
#   '새벽감성',
#   'RnB',
#   'midnight',
#   '멜랑꼴리',
#   '끈적',
#   'SLOWJAM'],
#  81: ['재즈추천', '황덕호', 'Jazz', '원더풀재즈', '재즈'],
#  82: ['기분좋은',
#   '팝',
#   '산책',
#   '여행',
#   '기분전환',
#   '외출',
#   '싱그러운',
#   '락',
#   '얼터너티브',
#   '산뜻한',
#   '전력질주',
#   '스포츠',
#   '인터벌',
#   '달리기',
#   'Rock',
#   '러닝',
#   '락',
#   '운동',
#   '기분전환',
#   '새벽',
#   '추석',
#   '귀성길',
#   '드라이브',
#   '귀경길',
#   '졸음퇴치',
#   '운전',
#   '신나는',
#   '달리기',
#   '운동',
#   '기분좋은',
#   '한강',
#   '운동',
#   '드라이브',
#   '기분전환',
#   '락앤롤'],
#  83: ['힐링',
#   '휴식',
#   '잔잔한',
#   '봄',
#   '설렘',
#   '사랑',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '소울',
#   '알앤비',
#   '휴식',
#   '힐링',
#   '기분전환',
#   '운동',
#   '새벽',
#   '밤',
#   '설렘',
#   '사랑',
#   '커플',
#   '봄',
#   '로맨틱',
#   '달달한',
#   '달콤',
#   '연애',
#   '로맨스',
#   '사랑',
#   '썸',
#   '매장음악',
#   '운동',
#   '장르스테디',
#   '명곡',
#   '포크',
#   '드라이브',
#   '국내',
#   '가요',
#   '스테디',
#   '포크스테디',
#   '감성적인',
#   '인기',
#   'kpop',
#   '발라드',
#   '스트레스',
#   '댄스',
#   'OST',
#   '기분전환',
#   '장르불문',
#   '중독',
#   '팝',
#   '인디',
#   '팝',
#   '기분전환',
#   '드라이브',
#   '가을',
#   '주말',
#   '드라이브',
#   '여행',
#   '고속도로',
#   '연애',
#   '데이트',
#   '썸',
#   '운전',
#   '일요일',
#   '신나는',
#   '악동뮤지션',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '여행',
#   '까페',
#   '산책',
#   '설렘',
#   '사랑',
#   '여름',
#   '시원',
#   '청량',
#   '드라이브',
#   '여행',
#   '바다',
#   '무더위',
#   '휴식',
#   '힐링',
#   '까페',
#   '악뮤',
#   '팬임',
#   '양희은악뮤콜라보',
#   '30대',
#   '여행',
#   '가을',
#   '산책',
#   '힙합',
#   '랩',
#   '스트레스',
#   '기분전환',
#   '신나는',
#   '헬스',
#   '아침',
#   '아이돌',
#   '다이어트',
#   '걸그룹',
#   '운동',
#   '조깅',
#   '내적댄스',
#   '스트레스',
#   '댄스',
#   '다리꼬지마',
#   '어떻게',
#   '악동뮤지션',
#   '오랜날',
#   '악뮤',
#   '기분전환',
#   '봄',
#   '슬픔',
#   '이별',
#   '설렘',
#   '사랑',
#   '카페',
#   '설레임',
#   '봄',
#   '설렘',
#   '봄날',
#   '감성',
#   '청량',
#   '스윗튠',
#   '위로',
#   '취향',
#   '일렉트로닉',
#   '노래가사',
#   '가사좋은',
#   '감성',
#   '드라이브',
#   '기분전환',
#   '인디',
#   '여행',
#   '드라이브',
#   '산책',
#   '스트레스',
#   '기분전환',
#   '휴식',
#   '힐링',
#   '설렘',
#   '사랑',
#   '잔잔한',
#   '밤',
#   '새벽',
#   '백업',
#   '인디',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '발라드',
#   '매장음악',
#   '까페',
#   '일렉',
#   '힐링',
#   '휴식',
#   '겨울',
#   '힐링',
#   '휴식',
#   '까페',
#   '추억',
#   '까페',
#   '회상',
#   '카드',
#   '악동뮤지션',
#   '투모로우바이투게더',
#   '위너',
#   '마마무',
#   '방탄소년단',
#   '아이유',
#   '아이콘',
#   '윤하',
#   '이하이',
#   '헬스장',
#   '운동',
#   '기분전환',
#   '매장음악',
#   '여행',
#   '산책',
#   '밤',
#   '새벽',
#   '여행',
#   '감성',
#   '봄',
#   '봄노래',
#   '드라이브',
#   '봄날',
#   '봄날씨',
#   '사랑',
#   '벚꽃',
#   '봄봄봄',
#   '셋리스트',
#   '공연',
#   '매장음악',
#   '설렘',
#   '사랑',
#   '기쁨',
#   '사랑',
#   '평화',
#   '웃음',
#   '소울',
#   '알앤비',
#   '기분전환',
#   '까페',
#   '순정',
#   '가을',
#   '사랑',
#   '악동뮤지션',
#   '명곡',
#   '밤',
#   '잔잔한',
#   '추운겨울',
#   '카페에서',
#   '국내',
#   '이불속',
#   '버스안',
#   '인디',
#   '케이팝스타',
#   '악뮤',
#   '이찬혁',
#   '악동뮤지션',
#   '이수현',
#   '감성',
#   '발라드',
#   '슬픔',
#   '국내',
#   '위로',
#   '이별',
#   '달달',
#   '고백',
#   '연애',
#   '설렘',
#   '사랑',
#   '아이돌',
#   '명곡',
#   '수록곡',
#   '명반',
#   '소울',
#   '알앤비',
#   '운동',
#   '설렘',
#   '사랑',
#   '사랑노래',
#   '짝사랑',
#   '설렘',
#   '마음',
#   '사랑',
#   'YG',
#   '02',
#   '03',
#   '티아라',
#   '04',
#   '05',
#   '빅뱅',
#   '분위기전환',
#   '추억',
#   '걸스데이',
#   '씨스타',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '인디',
#   '감성',
#   '봄캐롤',
#   '주말',
#   '사랑',
#   '휴식',
#   '설렘',
#   '산책',
#   '힐링',
#   '인디',
#   '봄',
#   '봄',
#   '설렘',
#   '사랑',
#   '여행',
#   '까페',
#   '산책'],
#  84: ['뉴에이지'],
#  85: ['취향저격', '팝', '몽환', 'Pop', 'Rock', '락'],
#  86: ['클래식', 'voice'],
#  87: ['기분전환',
#   '여름',
#   '드라이브',
#   '비오는날',
#   '매장음악',
#   '운동',
#   '분위기',
#   '드라이브',
#   '퇴폐',
#   '섹시',
#   '스트레스',
#   '신나는',
#   '밴드',
#   '팝',
#   '스트레스',
#   '기분전환',
#   '여성보컬',
#   '락',
#   '인디',
#   '비오는날',
#   '감성',
#   '밤',
#   '새벽',
#   '분위기',
#   '퇴폐',
#   '치명',
#   '기분전환',
#   '섹시',
#   '휴일',
#   '휴식',
#   '카페',
#   '여행',
#   '기분전환',
#   '팝'],
#  88: ['20대_국회의원선거', '4월_13일_꼭_투표하세요'],
#  89: ['재즈추천', '황덕호', 'Jazz', '원더풀재즈', '재즈'],
#  90: ['패션', '매장', '댄스', '클럽', 'Fashion'],
#  91: ['뉴에이지'],
#  92: ['록', '파워', '에너지', 'Metal', '메탈', 'Rock', '운전', '락'],
#  93: ['드라이브',
#   '봄',
#   '옷가게',
#   '해외감성',
#   '매장음악',
#   '카페',
#   '외국감성',
#   '최신POP',
#   '밤',
#   '혼자',
#   '오후',
#   'Pop',
#   '퇴근길',
#   '팝',
#   '버스',
#   'dance',
#   'Band',
#   'Pop',
#   'Rock'],
#  94: ['헤비메탈', '록', '불금', '기분전환', '입문', 'Rock', '락', '신나는'],
#  95: ['기분전환',
#   '설렘',
#   '사랑',
#   '기분전환',
#   '잔잔한',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '힐링',
#   '휴식',
#   '설렘',
#   '사랑',
#   '발라드',
#   '댄스',
#   '여행',
#   '운동',
#   '산책',
#   '카페',
#   '드라이브',
#   '여행',
#   '힐링',
#   '기분전환',
#   '스트레스',
#   '달달한노래',
#   '연애중',
#   '연애노래',
#   '달달',
#   '행복',
#   '연애',
#   '설렘',
#   '사랑',
#   '썸',
#   '앤씨아',
#   '기분전환',
#   '운동',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '드라이브',
#   '밤',
#   '새벽',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '네생각',
#   '잔잔한',
#   '추억',
#   '회상',
#   '겨울',
#   '운동',
#   '여름',
#   '짝사랑',
#   '즐거워',
#   '연애',
#   '기분전환',
#   '사랑',
#   '여행',
#   '신나는',
#   '댄스',
#   '여행',
#   '기분전환',
#   '산책',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '썸',
#   'FOREVER',
#   '팝송',
#   '가을',
#   '빌보드',
#   '봄',
#   '설렘',
#   '사랑',
#   '명곡',
#   '추천곡',
#   '실력파',
#   '아이돌',
#   '힙합',
#   '랩',
#   '회상',
#   '추억',
#   '선생님',
#   '그리움',
#   '스승의날',
#   '학교',
#   '친구',
#   '소울',
#   '알앤비',
#   '슬픔',
#   '이별',
#   '잔잔한',
#   '여성보컬',
#   '솔로가수',
#   '귀호강',
#   '목소리꿀',
#   '설렘',
#   '사랑'],
#  96: ['힐링', '휴식', '추억', '회상'],
#  97: ['잔잔한', '설렘', '사랑', '잔잔한', '설렘', '사랑', '봄', '설렘', '사랑'],
#  98: ['매장음악', '카페음익', '감성', '뉴에이지', '잔잔한', '카페음익', '감성', '매장음악', '가을', '잔잔한'],
#  99: ['힐링', '휴식'],
#  100: ['재즈'],
#  101: ['영계', '델리민주', '작업할때', '공부할때듣는음악', '공부할때', '환상적', '천국', '일렉'],
#  102: ['도깨비',
#   '오에스티',
#   '명장면',
#   '추억',
#   'OST',
#   '이번생은처음이라',
#   '인생드라마',
#   '드라마',
#   '명작',
#   '감성',
#   '카페',
#   '가을',
#   '잔잔한',
#   '새벽',
#   'OST',
#   '슬픔',
#   '낙엽',
#   '편안',
#   '잠들기전',
#   '위로',
#   '발라드',
#   '동심',
#   '행복',
#   '순수',
#   '맑음',
#   '힐링',
#   '설렘',
#   '사랑',
#   '동화',
#   '듣기좋은음악',
#   '아이유',
#   'OST',
#   '드라마',
#   '듣기좋은노래',
#   '호텔델루나',
#   '호텔델루나OST',
#   '발라드추천곡',
#   '발라드',
#   '힐링',
#   '휴식',
#   '기분전환'],
#  103: ['훵키', 'funky', '그루브', '신나는'],
#  104: ['힐링', '기분전환', '재즈', '연주곡', '잔잔한'],
#  105: ['락'],
#  106: ['클래식'],
#  107: ['일렉',
#   '일렉',
#   '일렉',
#   '일렉',
#   '클럽',
#   '매장음악',
#   '일렉',
#   '일렉',
#   '일렉',
#   '힙합',
#   '랩',
#   '드라이브',
#   '운동',
#   '클럽',
#   '드라이브',
#   '일렉',
#   '클럽',
#   '기분전환'],
# ...
#   'MartinGarrix',
#   'UMFkorea',
#   '하우스',
#   '일렉트로',
#   '신나는',
#   '빌로우',
#   'EDMFloor',
#   '일렉',
#   '이디엠',
#   'EDM',
#   '일렉',
#   '일렉',
#   '힙합',
#   '랩',
#   'EDM',
#   '스웨디시하우스마피아',
#   '일렉트로니카',
#   '빌로우',
#   '신나는',
#   '축제',
#   '클럽',
#   '운동',
#   'Festival',
#   'EDM',
#   '불금',
#   '페스티벌',
#   '파티',
#   '즐거운',
#   '신나는',
#   '힙합',
#   '랩'],
#  946: ['추억', '기분전환', '회상'],
#  947: ['힙합',
#   '감성힙합',
#   '띵곡',
#   '알앤비',
#   'RnB',
#   '잔잔',
#   '새벽',
#   'HipHop',
#   '트렌디',
#   '국힙',
#   '힙합',
#   '중독성',
#   '후렴',
#   '국힙',
#   '아무생각없이',
#   '감성',
#   '밤',
#   '알앤비',
#   '취향저격',
#   '분위기',
#   '그루브',
#   '유니크',
#   '인디',
#   '새벽'],
#  948: ['여름', '휴식', '매장음악', '스트레스', '드라이브', 'Pop', '여행', '기분전환', '팝'],
#  949: ['쇼미더머니6',
#   '쇼미더머니5',
#   '힙합',
#   '노래모음',
#   '인디고뮤직',
#   '국내힙합',
#   '노엘',
#   '쇼미더머니',
#   'Noel',
#   '고등래퍼',
#   '한국힙합',
#   '국힙',
#   '힙합',
#   'ytc4lyf',
#   'rakon',
#   '랩',
#   'Woodiegochild',
#   'dox_a',
#   'slo',
#   '크루',
#   'zenethezilla',
#   '힙합',
#   '여름',
#   '알앤비',
#   'RnBR',
#   'RnB',
#   '힙페',
#   '페스티벌',
#   '셋리스트',
#   '청춘'],
#  950: ['추억', '회상', '힐링', '휴식'],
#  951: ['뉴에이지'],
#  952: ['댄스',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '군인',
#   '군대',
#   '곰신',
#   '이등병',
#   '고무신',
#   '군입대',
#   '훈련소',
#   '기분전환',
#   '드라이브',
#   '댄스',
#   '발라드',
#   '댄스',
#   '스트레스',
#   '기분전환',
#   '힙합',
#   '한국힙합',
#   'MC',
#   '래퍼',
#   '힙합',
#   '7080',
#   '음악',
#   '락',
#   '발라드',
#   '힙합',
#   '랩',
#   '배치기',
#   '사이드비',
#   'MC스나이퍼',
#   '힙합전설',
#   '주석',
#   '국내힙합',
#   '얀키',
#   '프리스타일',
#   '드렁크타이거',
#   '힙합',
#   '클럽',
#   '홍대',
#   '콘서트',
#   '랩',
#   '공연',
#   '레이블',
#   '힙합',
#   '랩',
#   '1985',
#   '발라드',
#   '인기가요',
#   '추억',
#   '드라이브',
#   'OST',
#   '다이어트',
#   '탑골가요',
#   '이별',
#   '신나는',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '합',
#   '좋아요',
#   '국내힙합',
#   '국내',
#   'HipHop',
#   'KHIPHOP',
#   '힙',
#   '국힙',
#   '힙합',
#   '랩',
#   '힙합',
#   '추억',
#   'HipHop',
#   '추천노래',
#   '레트로',
#   '2000년대',
#   '90년대',
#   '신나는',
#   '힙합',
#   '랩',
#   '명곡',
#   '국내힙합',
#   'HipHop',
#   '명반',
#   'Rap',
#   '한국힙합',
#   '매장음악',
#   '기분전환',
#   '힙합',
#   '랩',
#   '스트레스',
#   '운동',
#   '힙합',
#   '랩',
#   '스트레스',
#   '기분전환',
#   '여름',
#   '스트레스',
#   '추억',
#   '운동',
#   '회상',
#   '댄스',
#   '여행',
#   '드라이브',
#   '산책',
#   '클럽',
#   '스트레스',
#   '힙합',
#   '여름',
#   '테크노',
#   '버즈',
#   '고전',
#   'god',
#   '댄스',
#   '드라이브',
#   '여행',
#   '스트레스',
#   '기분전환',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '알앤비',
#   '랩',
#   '음색',
#   '랩비트페스티벌',
#   '페스티벌',
#   '비트',
#   '2019',
#   '스트레스',
#   '신나는',
#   '러블리즈',
#   '콘서트셋리스트'],
#  953: ['휴식', '밤', '카페', '매장', '재즈', '힐링', '홈카페'],
#  954: ['클럽', '클럽', '일렉', '신나는'],
#  955: ['프로듀스48', '해외', '드라이브', '일본', '기분전환', 'JPOP', '인디', 'JPOP'],
#  956: ['비',
#   '카페',
#   '운동',
#   '드라이브',
#   '기분전환',
#   '이별',
#   '스트레스',
#   '음악추천',
#   '새벽감성',
#   '느낌있는',
#   '밤',
#   '그루브',
#   '새벽감성',
#   '새벽에',
#   '그루브',
#   '밤',
#   '드라이브',
#   '여행',
#   '기분전환',
#   '바다',
#   '밤바다',
#   '감성',
#   '밤',
#   '썸남썸녀',
#   '연인',
#   '분위기',
#   '드라이브',
#   '심쿵',
#   '섹시',
#   '섹시한느낌',
#   '팝송추천'],
#  957: ['겨울', '휴식', '카페', '발라드', '눈', '드라이브', '여행', '노래', '사랑', '이별'],
#  958: ['트로트'],
#  959: ['여러가지', '90'],
#  960: ['휴식같은음악', '커피', '힐링', '휴식'],
#  961: ['매장음악', '까페', '인디추천', '인디힙합', '누구나좋아하는힙합', '비오는날', '이별', '비', '카페'],
#  962: ['영계', '델리민주', '작업할때', '공부할때듣는음악', '공부할때', '환상적', '천국', '일렉'],
#  963: ['락', 'glamrock', '70년대', '글램록'],
#  964: ['밤',
#   '가을',
#   '낭만',
#   '별밤',
#   '달',
#   '재즈',
#   '하늘',
#   '별',
#   '밤',
#   '카페',
#   '잔잔한',
#   '보사노바',
#   'Jazz',
#   '커피',
#   '조용한'],
#  965: ['90s', '그루비', '올드스쿨', 'RnB', '감각적인', 'soul', '90sRnB', '리드미컬', '분위기있는'],
#  966: ['CCM'],
#  967: ['클럽', '밤', '새벽'],
#  968: ['발라드'],
#  969: ['락'],
#  970: ['클래식AtoZ', '바흐'],
#  971: ['가요', '기분전환', '설렘', '사랑'],
#  972: ['스트레스',
#   '기분전환',
#   '힙합',
#   'thexx',
#   '샘파',
#   '팝신곡',
#   '상콤달콤',
#   '런던오코너',
#   'sampha',
#   '강앤뮤직',
#   '봄맞이플레이리스트',
#   '일렉트로닉',
#   '힙합',
#   '드라이브뮤직',
#   '팝',
#   '재즈',
#   '일렉트로닉'],
#  973: ['휴일', '여유', '아침', '상쾌함', '기분전환', '즐거운'],
#  974: ['힙합',
#   '랩',
#   '슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '발라드',
#   '힐링',
#   '휴식',
#   '추억',
#   '회상',
#   '힙합',
#   '랩',
#   '발라드',
#   '힙합',
#   '랩',
#   '추억',
#   '회상',
#   '랩',
#   '힙합',
#   '힙합',
#   '랩'],
#  975: ['산책', '드라이브', '여행', 'EDM', 'NCS', '브금', '일렉', '일렉'],
#  976: ['연말',
#   '크리스마스캐롤',
#   'christmas_carol',
#   '메리크리스마스',
#   '성탄절',
#   '크리스마스',
#   '캐롤',
#   '화이트크리스마스',
#   'Carol',
#   'Christmas'],
#  977: ['추억',
#   '회상',
#   '뉴에이지',
#   '새벽',
#   '추억',
#   '밤',
#   '회상',
#   '뉴에이지',
#   '고막남친',
#   '책방',
#   '카페',
#   '피아노',
#   '고막난로',
#   '독서',
#   '따뜻한',
#   '편한',
#   '책',
#   '북카페'],
#  978: ['CCM', 'CCM', '둘새', '찬양', '기독교', '교회', '국내ccm'],
#  979: ['팝',
#   '클럽',
#   '메이드',
#   '클럽노래',
#   'EDM',
#   'UMF',
#   '강남',
#   '아레나',
#   '일렉',
#   '스트레스',
#   '신나는',
#   '클럽',
#   'dance',
#   '드라이브',
#   '클럽음악',
#   'EDM',
#   'electronica',
#   'HipHop',
#   'Club',
#   '여행',
#   '신나는',
#   '클럽',
#   '하우스',
#   '클럽',
#   'Club',
#   '클럽음악',
#   '드라이브',
#   'EDM',
#   '스트레스',
#   'Electronic',
#   '신나는'],
#  980: ['힙합',
#   '노래모음',
#   '바이올린',
#   '엠비션뮤직',
#   '릴러말즈',
#   '국내힙합',
#   '비트',
#   '작업곡',
#   '한국힙합',
#   '국힙',
#   'RnB',
#   '트렌디',
#   'PBRnB',
#   'good',
#   '감성힙합',
#   '힙합',
#   '한국힙합',
#   '국힙',
#   '싱잉',
#   '랩',
#   '야망',
#   '릴러말즈',
#   '엠비션뮤직'],
#  981: ['OST',
#   '감성',
#   '매장음악',
#   '연주곡',
#   '피아노',
#   '위로',
#   '커피',
#   '뉴에이지',
#   '부드럽고',
#   '쉼',
#   '편안한',
#   '운동',
#   '잔잔한',
#   '뉴에이지',
#   '힐링',
#   '휴식',
#   '잔잔한',
#   '겨울',
#   '감성',
#   '감성자극',
#   '비',
#   '가을',
#   '발라드',
#   '우울',
#   '센치',
#   '저녁',
#   '밤',
#   '뉴에이지',
#   '매장음악',
#   '까페',
#   '집에가는길',
#   '집',
#   '귀가',
#   '토닥토닥',
#   '수고했어요',
#   'OST',
#   '영화',
#   '매장음악',
#   '장마',
#   '카페',
#   '연주곡',
#   '뉴에이지',
#   '까페',
#   '비',
#   '매장음악',
#   '가을',
#   '여름',
#   '기분전환',
#   '힐링',
#   '휴식',
#   '추억',
#   '회상',
#   '휴식',
#   '힐링',
#   '뉴에이지',
#   '카페음악',
#   '감성',
#   '매장음악',
#   '연주곡',
#   '일본애니메이션ost',
#   '일본애니메이션',
#   'OST',
#   '영화음악',
#   '여름',
#   '힐링',
#   '휴식',
#   '슬픔',
#   '이별',
#   '잔잔한',
#   '비오는날',
#   '휴식',
#   '잔잔한',
#   '피아노',
#   '커피',
#   '힐링',
#   '뉴에이지',
#   '까페',
#   '고요함',
#   '잔잔',
#   '피아노',
#   '뉴에이지',
#   '공부할때',
#   '일본애니메이션',
#   'OST',
#   '뉴에이지',
#   '애니',
#   '애니메이션',
#   '애니메이션OST',
#   '휴일',
#   '감성',
#   '카페',
#   '드라이브',
#   '여행',
#   '휴식',
#   '기분전환',
#   '사랑',
#   '힐링',
#   '신나는',
#   '힐링',
#   '휴식',
#   '까페',
#   '뉴에이지',
#   '기분좋은',
#   '감성',
#   '연주곡',
#   '월요일',
#   '피아노',
#   '클래식',
#   '힐링',
#   '뉴에이지',
#   '매장음악',
#   '까페',
#   '매장음악',
#   '까페',
#   '태교음악',
#   '감성',
#   '태교',
#   '피아노',
#   'EQ지수',
#   '힐링',
#   '뉴에이지',
#   '임산부',
#   '아이',
#   '자장가',
#   '집중',
#   '여름',
#   '출근길',
#   '아침',
#   '하루',
#   '독서',
#   '휴식',
#   '뉴에이지',
#   '모닝커피',
#   '힐링',
#   '들을수록',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '가을',
#   '까페',
#   '피아노',
#   '연주곡',
#   '애니',
#   '지브리',
#   'OST',
#   '일본',
#   '독서',
#   '잠들기전',
#   '공부',
#   '편안한',
#   '힐링',
#   '휴식',
#   '추억',
#   '잔잔한',
#   '뉴에이지',
#   '잔잔한',
#   '음악',
#   '편안한',
#   '뉴에이지',
#   '힐링',
#   '휴식',
#   '감성',
#   '매장음악',
#   '연주곡',
#   '잔잔한',
#   '오후',
#   '피아노',
#   '위로',
#   '힐링',
#   '뉴에이지',
#   '커피숍',
#   '힐링',
#   '휴식',
#   '잔잔한',
#   '카페음악',
#   '감동',
#   '쉼',
#   '라운지',
#   '카페',
#   '연주곡',
#   '포근한',
#   '여행',
#   '독서',
#   '일상',
#   '설렘',
#   '데이트',
#   '여름휴가',
#   '휴식',
#   '감성',
#   '잔잔한',
#   '취향저격',
#   '잔잔',
#   '신나는',
#   'ASMR',
#   '휴식',
#   '좋은기분',
#   '잔잔한',
#   '드라이브',
#   '여행',
#   '감성',
#   '뉴에이지',
#   '사랑',
#   '기분전환',
#   '없다',
#   '기분전환',
#   '까페',
#   '가사없음',
#   '삽입곡',
#   'OST',
#   '광고음악',
#   '힐링',
#   '지브리',
#   '추억',
#   '평화',
#   '토토로',
#   '지브리',
#   'OST',
#   '애니메이션',
#   '휴식',
#   '감성',
#   '영화',
#   '고전',
#   '발라드',
#   '밤',
#   '연주곡',
#   '잔잔한',
#   '달달',
#   '새벽',
#   '기분전환',
#   '뉴에이지',
#   '잔잔한',
#   '공부할때',
#   '잔잔한',
#   '낮잠',
#   '오후',
#   '재즈',
#   '낮',
#   '뉴에이지',
#   '카페음악',
#   '매장음악',
#   '매장',
#   '피아노',
#   'cafe',
#   '카페',
#   '연주곡',
#   'xjapan',
#   'dadaray',
#   '게스노키와미오토메',
#   '겨울',
#   '연말',
#   '혼자있을때',
#   '크리스마스',
#   'indigo_la_end',
#   'JPOP',
#   '라르크앙시엘',
#   '영화OST',
#   '혼자',
#   '잔잔한',
#   '새벽',
#   'OST',
#   '조용한',
#   '영화',
#   '가사없는',
#   '영화음악',
#   '밤',
#   '뉴에이지',
#   '시작',
#   '히사이시조',
#   '지브리',
#   '센과치이로의행방불명',
#   '인생의회전목마',
#   '미야자키하야오',
#   '매장음악',
#   '카페',
#   '연주곡',
#   '잔잔한',
#   '배경음',
#   '추억',
#   '독서',
#   '뉴에이지',
#   '까페',
#   '호텔',
#   '일본애니',
#   '추억',
#   '기분전환',
#   '애니메이션',
#   '연주곡',
#   '피아노',
#   '뉴에이지',
#   '잠들기전',
#   '자장가',
#   '잠안올때',
#   '휴식',
#   '힐링',
#   '기분전환',
#   '매장음악',
#   '까페',
#   '매장',
#   '겨울',
#   '감성',
#   '매장음악',
#   '카페',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '여름',
#   '까페',
#   '매장음악',
#   '비',
#   '카페',
#   '발라드',
#   '드라이브',
#   '재즈',
#   '힐링',
#   '기분전환',
#   '인디',
#   '일렉',
#   '연주곡',
#   '피아노',
#   '연주',
#   '클래식',
#   '힐링',
#   '재즈',
#   '잔잔',
#   '힐링',
#   'bgm',
#   '뉴에이지',
#   '잔잔한',
#   '추억',
#   '회상',
#   '기분전환',
#   '휴식',
#   '행복',
#   '공부',
#   '잔잔한',
#   '겨울',
#   '휴식',
#   '잔잔한',
#   '새벽',
#   '독서',
#   '뉴에이지',
#   '피아노',
#   '기분전환',
#   '힐링',
#   '피아노',
#   '가을',
#   '저녁',
#   '연주곡',
#   '봄',
#   '연주곡',
#   '달달',
#   '피아노',
#   '그리움',
#   '힐링',
#   '뉴에이지',
#   '설렘',
#   '퇴근길',
#   '팝',
#   '굿밤',
#   '밤',
#   '새벽',
#   '비오는날',
#   '밤',
#   '새벽',
#   '뉴에이지',
#   '숙면',
#   '뉴에이지피아노',
#   '힐링',
#   '휴식',
#   '가을',
#   'OST',
#   '피아노',
#   '뉴에이지',
#   '연주곡',
#   '추억',
#   '감성',
#   'OST',
#   '애니메이션',
#   '히사이시조',
#   'Pring',
#   '뉴에이지',
#   '뉴에이지',
#   '힐링',
#   '휴식',
#   '기분전환',
#   '뉴에이지',
#   '뉴에이지',
#   '휴식',
#   '피아노',
#   '영화음악',
#   '봄',
#   'OST',
#   '벚꽃',
#   '동심',
#   '해외',
#   '사운드트랙',
#   '감동',
#   '명곡',
#   'OST',
#   '애니메이션',
#   '영화',
#   '명작',
#   '듣기좋은',
#   '잔잔한',
#   '피아노',
#   '아름다운선율',
#   '뉴에이지',
#   '새벽감성잔잔한',
#   'OST',
#   'OST',
#   '카페',
#   '클래식',
#   '지브리',
#   '미야자키하야오',
#   '무라카미하루키',
#   '커피',
#   '카페',
#   '산책',
#   '감성',
#   '연주곡',
#   '새벽',
#   '피아노',
#   '클래식',
#   '힐링',
#   '뉴에이지',
#   '자장가',
#   '편안한',
#   '매장음악',
#   '카페음악',
#   '뉴에이지',
#   '뉴에이지피아노',
#   '뉴에이지',
#   '휴식',
#   '연주곡',
#   '일기장',
#   '피아노',
#   '힐링',
#   '뉴에이지',
#   '숙면',
#   '편안한',
#   '집중',
#   '공부할때',
#   '추억',
#   '기분전환',
#   '회상',
#   '여름',
#   '여행',
#   '산책',
#   '우울할때',
#   '쓸쓸',
#   '새벽에',
#   '집중',
#   '휴식',
#   '카페',
#   '매장',
#   '힐링',
#   '뉴에이지',
#   '연주음악',
#   '생각',
#   '공부',
#   '북카페',
#   '뉴에이지',
#   '집중',
#   '잔잔한',
#   '가사없는',
#   '공부할때',
#   '감동',
#   'OST',
#   '드라마',
#   '기분전환',
#   '영화',
#   '영화OST',
#   '드라마ost',
#   '애니매이션',
#   '감성',
#   '월요병',
#   '클래식',
#   '휴식',
#   '힐링',
#   '뉴에이지',
#   '사랑',
#   '러브',
#   '분위기',
#   'OST',
#   '영화',
#   'uuuu',
#   '지누지누',
#   '매장음악',
#   '까페',
#   '겨울왕국2',
#   '보스베이비',
#   '너의이름은',
#   '가사없는음악',
#   '클래식',
#   '겨울왕국',
#   '주먹왕랄프',
#   '드래곤길들이기3',
#   '이누야샤',
#   '애니매이션',
#   '뉴에이지',
#   '비오는날',
#   '여름',
#   '휴식',
#   '밤',
#   '회상',
#   '잔잔한',
#   '힐링',
#   '기분전환',
#   '사랑',
#   '비오는날',
#   '추천곡',
#   '매장음악',
#   '카페',
#   '매장',
#   '힐링',
#   '일상',
#   '비오는날',
#   '휴식',
#   '힐링',
#   '감성',
#   '여유',
#   '오후',
#   'OST',
#   '애니메이션',
#   '영화',
#   '영화OST',
#   '팝',
#   '휴식',
#   '힐링',
#   '여행',
#   '산책',
#   '어서와이건처음이지',
#   '감성',
#   '브금',
#   '뉴에이지',
#   '지브리',
#   '동심',
#   '연주노래',
#   '추억',
#   '공부',
#   'OST',
#   '애니메이션',
#   '뉴에이지',
#   '디즈니',
#   '애니음악',
#   '신비로운',
#   '비오는날',
#   '밤',
#   '신비',
#   '몽환',
#   '뉴에이지',
#   '뉴에이지',
#   '밤',
#   '잔잔한',
#   '피아노',
#   '슬픔',
#   '힐링',
#   '뉴에이지',
#   '설렘',
#   '회상',
#   '까페',
#   '기분좋은',
#   '추억',
#   '아이들',
#   '잔잔한',
#   '감동',
#   'OST',
#   '애니메이션',
#   '가족',
#   '지브리',
#   '힐링',
#   '뉴에이지',
#   '가을비',
#   '매장음악',
#   '가을',
#   '카페',
#   '매장',
#   '힐링',
#   '뉴에이지',
#   '여름',
#   '카페',
#   '드라이브',
#   '여행',
#   '기분전환',
#   '스트레스',
#   '신나는',
#   '잔잔한',
#   '힐링',
#   '감성',
#   '휴식',
#   '사랑',
#   '뉴에이지',
#   '집중',
#   '책',
#   '독서',
#   '일할때',
#   '뉴에이지',
#   '업무',
#   '공부',
#   '편안한',
#   '매장음악',
#   '카페',
#   '휴식',
#   '힐링',
#   '잔잔한',
#   '카페',
#   '커피',
#   '피아노',
#   '인스트루멘탈',
#   '연주곡',
#   '비오는날',
#   '휴식',
#   '힐링',
#   '출근',
#   '지하철',
#   '버스',
#   '아침',
#   '쌀쌀한',
#   '휴식',
#   '여행',
#   '매장음악',
#   '까페',
#   'OST',
#   '잠',
#   '연주곡',
#   'inst',
#   '가사없는',
#   '잠들기전',
#   'piano',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '지브리',
#   '공부',
#   '도서관',
#   '힐링',
#   '휴식',
#   '까페',
#   '오케스트라',
#   '클래식',
#   '피아노',
#   '영화OST',
#   '추천',
#   '매장음악',
#   '추천음악',
#   '카페',
#   '매장',
#   '식당',
#   '추천노래',
#   '매장노래',
#   '의류매장',
#   '헤어샵',
#   '집중',
#   '휴식',
#   '카페',
#   '매장',
#   '커피',
#   '힐링',
#   '뉴에이지',
#   '북카페',
#   '공부',
#   '까페',
#   '휴식',
#   '힐링',
#   '가을',
#   '휴식',
#   '힐링',
#   '기분전환',
#   '영화음악',
#   '영화삽입곡',
#   '노동요',
#   'OST',
#   '테마곡',
#   'OST',
#   '휴식',
#   '잔잔한',
#   '피아노',
#   '힐링',
#   '뉴에이지',
#   '자기전에',
#   '자장가',
#   '숙면',
#   '집중',
#   '감성',
#   '잔잔',
#   '피아노',
#   '클래식',
#   '뉴에이지',
#   '가사없는',
#   '경음악',
#   '수면유도',
#   '공부',
#   '생각이많을때',
#   '잠들기전',
#   '휴식',
#   '잔잔한',
#   '추억',
#   'OST',
#   '힐링',
#   '영화음악',
#   '카페음악',
#   '햇살',
#   '매장음악',
#   '카페',
#   '연주곡',
#   '기분좋은',
#   '태교',
#   '힐링',
#   '슬픔',
#   '이별',
#   '잔잔한',
#   '일하면서',
#   '뉴에이지',
#   'OST',
#   '뉴에이지',
#   '아침',
#   '연주곡',
#   '잔잔한',
#   '다이어트',
#   '피아노',
#   '상쾌한',
#   '클래식',
#   '뉴에이지',
#   '편안한',
#   '뉴에이지',
#   '자장가',
#   '뉴에이지',
#   '불면증',
#   '잠안올때',
#   '수면',
#   '잔잔한',
#   '겨울',
#   '토요일',
#   '매장음악',
#   '가을',
#   '잔잔한',
#   '휴식',
#   '기분전환',
#   '설렘',
#   '힐링',
#   '잔잔한',
#   '영화',
#   '영화OST',
#   '새벽',
#   'OST',
#   '감동',
#   '회상',
#   '추억',
#   'OST',
#   '애니메이션',
#   '영화OST',
#   '장르',
#   '지브리',
#   '영화음악',
#   '스코어',
#   '휴식',
#   '연주곡',
#   '피아노',
#   '드라이브',
#   '여행',
#   '힐링',
#   '뉴에이지',
#   '스트레스',
#   '쉼',
#   'OST',
#   '휴식',
#   '연주곡',
#   '잔잔한',
#   '애니메이션',
#   '힐링',
#   '뉴에이지',
#   '릴렉스',
#   '영화음악',
#   '연주곡',
#   'OST',
#   '영화OST',
#   '영화',
#   '분위기',
#   '매장음악',
#   '카페',
#   '매장',
#   '클래식',
#   '뉴에이지',
#   '피아노',
#   '휴식',
#   '힐링',
#   '잔잔한',
#   '힐링',
#   '휴식',
#   '매장음악',
#   '감성',
#   '주말',
#   '편안한',
#   '우울한날',
#   '위로',
#   '뉴에이지',
#   '연주곡',
#   '추억',
#   '회상',
#   '기분전환',
#   '까페',
#   '지브리',
#   '연주곡',
#   '피아노연주곡',
#   '명상',
#   'OST',
#   '애니메이션',
#   '오케스트라',
#   '피아노',
#   '디즈니',
#   '잔잔한연주곡',
#   '감성',
#   '연주곡',
#   '매장BGM',
#   '피아노',
#   '드라이브',
#   '여행',
#   '힐링',
#   '뉴에이지',
#   '스트레스',
#   '편안한',
#   '오후',
#   '뉴에이지',
#   '나른한',
#   'OST',
#   '잔잔한',
#   '추억',
#   '회상',
#   '힐링',
#   '휴식',
#   '잔잔한',
#   '카페',
#   '연주곡',
#   '피아노',
#   '매장BGM',
#   '힐링',
#   '뉴에이지',
#   '기분전환',
#   '비오는날',
#   '연주음악',
#   '피아노',
#   '비',
#   '기분전환',
#   '드라이브',
#   '여행',
#   '일본애니',
#   '만화영화',
#   '일본만화영화OST',
#   'OST',
#   '일본',
#   '영화OST',
#   '명작',
#   '일본만화영화',
#   '불면증',
#   '뉴에이지',
#   '분위기',
#   '카페',
#   '비오는날',
#   '휴식',
#   '카페',
#   '잔잔한',
#   '명상',
#   '클래식',
#   '기분전환',
#   '이별',
#   '스트레스',
#   '공부',
#   '힐링',
#   '휴식',
#   '까페',
#   '매장음악',
#   '카페',
#   '여유',
#   '힐링',
#   '뉴에이지',
#   '불면증',
#   '자장가',
#   '뉴에이지피아노',
#   '까페',
#   '여름',
#   '감성',
#   '밤',
#   '연주곡',
#   '잔잔한',
#   '피아노',
#   '뉴에이지',
#   '기분전환',
#   '매장음악',
#   '카페',
#   '연주곡',
#   '매장',
#   '힐링',
#   '뉴에이지',
#   '팝',
#   '휴식',
#   'OST로_귀이득',
#   '지브리',
#   '디즈니OST',
#   'OST모음',
#   '기분전환',
#   '픽사',
#   '애니매이션',
#   '기분전환',
#   '가을',
#   '슬픔',
#   '드라이브',
#   '이별',
#   '뉴에이지',
#   '연주곡',
#   '가을',
#   '피아노',
#   '그냥',
#   '유키구라모토',
#   '힐링',
#   '마음',
#   '이루마',
#   '누자베스',
#   '찡한날',
#   '카페음악',
#   '매장',
#   '매장음악',
#   '카페',
#   '연주곡',
#   '회상',
#   '추억',
#   '피아노',
#   '분위기',
#   '휘인',
#   '휘인추천곡',
#   '정휘인',
#   '마마무',
#   '기타',
#   '피아노',
#   '가사없는',
#   '뉴에이지',
#   '추억',
#   '영화OST',
#   '회상',
#   '만화',
#   '아이들',
#   '영화',
#   '애니메이션',
#   '잠',
#   '휴식',
#   '잔잔한',
#   '새벽',
#   '안정',
#   '독서',
#   '영화음악',
#   '영화',
#   '영화OST',
#   'OST',
#   '매장음악',
#   '연주곡',
#   '뉴에이지',
#   '호텔',
#   '카페',
#   'instumental',
#   'bgm',
#   'CF',
#   '연주곡',
#   '광고',
#   '히사이시조',
#   '피아노',
#   '매장음악',
#   '연주곡',
#   '카페',
#   '감성',
#   '뉴에이지',
#   '재즈',
#   '잔잔한',
#   '까페',
#   '잔잔한',
#   '겨울',
#   '매장음악',
#   '카페',
#   '연주곡',
#   '눈',
#   '뉴에이지',
#   '캐롤',
#   '까페',
#   '매장음악',
#   '카페',
#   '연주곡',
#   '매장',
#   '명상',
#   '클래식',
#   '가을',
#   '뉴에이지',
#   '편아한',
#   '공부',
#   '힐링',
#   '휴식',
#   '밤',
#   '새벽',
#   '카페음악',
#   '뉴에이지',
#   '매장음악',
#   '뉴에이지피아노',
#   ...],
#  982: ['감각적인', '감성', '매장음악', 'Pop', 'Pop'],
#  983: ['감성',
#   '카페',
#   '알앤비',
#   '분위기',
#   '그루브',
#   '기분전환',
#   '뉴욕',
#   '여행',
#   '하우스',
#   '소울',
#   '매장음악',
#   '카페',
#   '잔잔한',
#   'RnB',
#   '오후',
#   '분위기',
#   'Pop',
#   '와인',
#   '트렌디',
#   '감각적인'],
#  984: ['멜론키즈',
#   '키즈',
#   '테마곡',
#   '키즈송',
#   '만화',
#   '귀여운',
#   '기분전환',
#   '동요',
#   '신나는',
#   '만화주제가',
#   '아이들'],
#  985: ['락'],
#  986: ['힐링',
#   '휴식',
#   '까페',
#   '휴식',
#   '힐링',
#   '기분전환',
#   '매장음악',
#   '재즈',
#   '재즈',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '힐링',
#   '휴식',
#   '까페',
#   '기분전환',
#   '까페'],
#  987: ['소울', '알앤비', '팝', '비오는날', '잔잔한'],
#  988: ['힙합', 'B', '알앤비', '힙합DJ', '매니악', '매니아', '언더커버', '힙합리스트'],
#  989: ['댄스'],
#  990: ['컴필레이션', '국내록', '옴니버스', '락', '베스트앨범', '해외록', '메탈', '록'],
#  991: ['발라드'],
#  992: ['목소리',
#   '클럽',
#   '섹시',
#   '트렌디',
#   '알앤비',
#   '데일리뮤직',
#   'RnB',
#   '카페음악',
#   '감성',
#   '혼자',
#   '분위기있는',
#   '팝송',
#   '침대',
#   '드라이브음악',
#   '휴식',
#   '분위기깡패',
#   '카페',
#   '운동',
#   '걸으며듣기좋은',
#   '그루브',
#   '띵곡',
#   '띵곡모음',
#   '힙합',
#   '밤',
#   '알앤비',
#   '팝',
#   '분위기',
#   '그루브',
#   '기분전환',
#   '혼술',
#   'groove',
#   'Rap',
#   'indie',
#   'RnB',
#   '명곡',
#   'Pop',
#   '기분전환',
#   '명곡모음',
#   '필수',
#   '명반'],
#  993: ['CCM'],
#  994: ['비오는날', '여유', '피아노', '봄날', '클래식', '힐링', '뉴에이지', '날씨좋은날', '산책'],
#  995: ['힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙한_세련된',
#   '헬스장',
#   '운동',
#   '청소',
#   '스웩',
#   '파워풀_에너제틱',
#   '기분전환',
#   '비트감있는',
#   '스트레스',
#   '분위기있는',
#   '감성적인',
#   '드라이브',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '묵직한',
#   '랩',
#   '국내힙합',
#   '기분전환',
#   '비트',
#   '국내힙합_2',
#   '국내힙합_1',
#   '스트레스',
#   '명곡',
#   '국내힙합',
#   '힙합',
#   '스트레스',
#   '기분전환',
#   '운동',
#   '감성',
#   '힙합',
#   '랩',
#   '힙합',
#   'HipHop',
#   '붐뱁',
#   '힙합',
#   '랩',
#   '여행',
#   '기분전환',
#   '산책',
#   '내가듣고싶어서만든플레이리스트',
#   '한국힙합',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '힙합',
#   '랩',
#   '국힙',
#   '신선',
#   '올드스쿨',
#   '강렬',
#   '붐뱁',
#   'badass',
#   'backward',
#   '힙합',
#   '랩',
#   '유망주',
#   '정규1집',
#   '힙합',
#   '랩',
#   '팝',
#   '스트레스',
#   '드라이브',
#   '힙합',
#   '랩',
#   '힙합',
#   'SWAG',
#   '반복재생',
#   'HipHop',
#   '붐뱁',
#   '명반',
#   '드럼앤베이스',
#   '힙합',
#   '랩',
#   '힙합',
#   '하이라이트',
#   '국내힙합',
#   '힙합',
#   '봄',
#   '랩',
#   '기분전환',
#   '국산',
#   '김치',
#   '한국힙합',
#   '국힙',
#   '점심',
#   '신나는',
#   '좋아요',
#   '내취향',
#   '최애곡',
#   '플레이리스트',
#   '나만의'],
#  996: ['cepa', '피아노연주곡'],
#  997: ['OST'],
#  998: ['힙합',
#   'BoomBap',
#   '랩',
#   'HipHop',
#   '붐뱁',
#   '외힙',
#   '스트레스',
#   '힙합',
#   'DJ프리미어',
#   'Producer',
#   '이스트코스트',
#   '프로듀서',
#   'Premier',
#   '재즈랩',
#   '둔탁한',
#   '해외힙합',
#   '붐뱁'],
#  999: ['키즈동요', '아기동요'],
#  ...}

# %%
tags_result = list(song_id_to_tags_dict.values())
tags_result[0:3]
# Out:
# [['비오는날', '드라이브', '비오는날', '추억', '회상'],
#  ['1',
#   '감성',
#   '듣기좋은',
#   '드라이브',
#   'Pop',
#   '여행',
#   '기분전환',
#   '팝',
#   '신나는',
#   '클럽',
#   '매장음악',
#   '드라이브',
#   'EDM모음',
#   '페스티벌',
#   '기분전환',
#   '스트레스',
#   '신나는',
#   'dance',
#   'house',
#   '여름',
#   'tropical',
#   '일렉',
#   '편집숍',
#   '힙스터',
#   '기분전환',
#   '운동',
#   '축제',
#   '클럽',
#   '운동',
#   'Festival',
#   'EDM',
#   '불금',
#   '페스티벌',
#   '파티',
#   '즐거운',
#   '신나는'],
#  ['뉴에이지', '뉴에이지']]

# %%
import multiprocessing

from gensim.models import Word2Vec

cores = multiprocessing.cpu_count()

# %%
w2v_model = Word2Vec(min_count=10,
                     window=3,
                     vector_size=300,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)

# %%
w2v_model.build_vocab(tags_result, progress_per=10000)

# %%
from time import time

t = time()
w2v_model.train(tags_result, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
print('Time to train the model: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to train the model: 5.91 mins

# %%
w2v_model.init_sims(replace=True)
# Out:
# <ipython-input-19-c7757d71a30b>:1: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v_model.init_sims(replace=True)

# %%
w2v_model.wv.most_similar(positive=["락"],topn=5)
# Out:
# [('록', 0.5531038045883179),
#  ('밴드', 0.5198248624801636),
#  ('팝', 0.48328331112861633),
#  ('Rock', 0.4813997745513916),
#  ('사실락만있는거아님', 0.45989060401916504)]

# %%
w2v_model.wv.most_similar(positive=["기분좋은"],topn=5)
# Out:
# [('행복', 0.5596479773521423),
#  ('데이트', 0.5584471821784973),
#  ('봄', 0.5303997993469238),
#  ('달달', 0.5176151990890503),
#  ('달달한', 0.5170160531997681)]

# %%
w2v_model.wv.most_similar(positive=["느긋한"],topn=5)
# Out:
# [('심심한', 0.5409355759620667),
#  ('한가한', 0.5254039764404297),
#  ('느긋느긋', 0.4906960725784302),
#  ('나긋나긋', 0.4282887578010559),
#  ('잔잔한그루브', 0.41279932856559753)]

# %%
len(w2v_model.wv)
# Out:
# 28733

# %%
word_vectors = w2v_model.wv

# %%
word_vectors.key_to_index['락']
# Out:
# 36

# %%
word_vectors.vectors[0:3]
# Out:
# array([[ 3.81622277e-02, -1.14798866e-01,  1.28130704e-01,
#         -4.91289385e-02, -5.75583288e-03,  7.88114369e-02,
#          2.82828938e-02,  4.22432609e-02,  5.75586110e-02,
#          5.10748960e-02,  1.03406971e-02,  8.57046098e-02,
#         -7.03828931e-02,  1.02196865e-01,  2.15622596e-02,
#          4.25093248e-02, -7.51991346e-02,  1.76750403e-02,
#          3.00971642e-02,  3.45339626e-02, -2.65563056e-02,
#         -7.60709401e-03, -4.86635230e-02,  2.51385476e-02,
#         -6.43797442e-02,  3.97076607e-02, -6.45420030e-02,
#         -3.96940410e-02,  4.20970470e-02,  6.62545580e-03,
#         -9.16856341e-03, -5.01071662e-02, -2.33782381e-02,
#         -6.81793094e-02, -4.57443967e-02, -7.34456405e-02,
#          1.40392510e-02,  4.49817963e-02, -7.61924917e-03,
#         -6.92717209e-02, -3.90361473e-02, -2.10036244e-02,
#          6.92797080e-02, -5.06780185e-02, -4.12618928e-03,
#         -2.88148895e-02, -1.01817027e-01, -6.05974570e-02,
#         -3.84988040e-02,  7.30151427e-04, -3.50716487e-02,
#          5.20005561e-02,  9.76004377e-02, -4.86314520e-02,
#         -2.40818672e-02, -5.51139712e-02, -3.65827861e-03,
#          1.31461039e-01,  1.37570631e-02, -1.24282070e-01,
#         -3.20722461e-02, -6.67254347e-03,  5.84300272e-02,
#         -3.85225378e-02,  1.21572748e-01, -3.68524939e-02,
#          2.40128692e-02,  6.58237338e-02,  6.48441017e-02,
#          5.38423955e-02, -5.63419005e-03, -9.56438035e-02,
#          3.99860442e-02,  2.73135826e-02, -8.21222663e-02,
#         -6.29765913e-03,  1.35350851e-02, -4.36100736e-02,
#         -2.06065271e-02, -9.06424597e-02,  4.42887954e-02,
#         -2.70820060e-03, -5.10706217e-04, -1.18118405e-01,
#          4.66967411e-02,  9.76259783e-02, -3.99736874e-02,
#          1.41394362e-02,  4.44597611e-03, -3.89400125e-02,
#         -5.72833698e-03, -3.32283825e-02, -3.88655029e-02,
#         -2.29564048e-02, -4.95045446e-02, -3.77490418e-04,
#         -7.59921446e-02, -8.59929100e-02,  1.33599013e-01,
#          7.45960772e-02,  1.39710739e-01,  3.02675981e-02,
#          8.84081125e-02,  4.03424799e-02, -1.46650216e-02,
#          1.07596060e-02,  3.41647565e-02, -3.96569781e-02,
#          1.67593267e-03,  6.47021160e-02,  6.04117988e-03,
#          3.23114060e-02, -7.69744515e-02, -5.47374189e-02,
#          3.12338527e-02,  5.30875637e-04,  2.47823298e-02,
#         -1.01091497e-01, -9.98148695e-02,  6.31005764e-02,
#         -7.14730844e-02, -8.01287219e-02, -2.37047719e-03,
#          1.92425698e-02,  8.12881254e-03,  6.70740530e-02,
#          6.15490302e-02,  9.71788391e-02,  3.57578718e-03,
#         -1.18347555e-02,  4.87432145e-02,  4.80284579e-02,
#          1.39479171e-02,  3.36588472e-02,  6.97000548e-02,
#         -2.60634441e-02, -3.57428454e-02,  9.53339506e-03,
#          3.55663374e-02, -5.59674315e-02, -5.55890091e-02,
#          3.15848887e-02,  7.03209713e-02,  8.48529115e-03,
#          6.90032765e-02, -1.89350173e-02, -8.31694715e-03,
#          1.58164054e-02,  3.70289385e-02,  6.22249842e-02,
#          2.19257064e-02,  5.75359352e-02,  3.04248836e-02,
#          1.00736208e-01, -2.01601163e-02,  5.11515364e-02,
#         -1.58260278e-02, -2.29063164e-02, -3.16100232e-02,
#         -5.60928397e-02,  3.74142989e-03, -3.37178446e-02,
#         -1.27179278e-02,  3.11802514e-02,  9.06263106e-03,
#         -1.54863104e-01, -2.30941363e-02, -5.26674464e-02,
#          3.06033008e-02, -9.50874761e-02,  7.25860894e-02,
#          6.92422688e-02,  1.75671149e-02, -1.72777064e-02,
#         -1.39953002e-01, -4.03775126e-02, -2.08712146e-02,
#          1.16725480e-02, -1.18639367e-02,  3.41064744e-02,
#          1.40942428e-02,  4.35143746e-02, -7.34723499e-03,
#          6.09749742e-03,  1.03079438e-01,  3.82353365e-02,
#         -7.26126954e-02, -9.00417343e-02, -7.01815560e-02,
#         -4.46586311e-02, -4.69852872e-02, -6.57194853e-02,
#          3.19625027e-02, -2.21949685e-02, -8.31528082e-02,
#         -4.96990094e-03,  9.66857094e-03,  2.61485185e-02,
#         -4.00338136e-02,  1.31176189e-02,  1.33268341e-01,
#          3.77510376e-02,  5.08098351e-03, -2.79379822e-02,
#          1.16570052e-02,  7.73237422e-02,  6.71844035e-02,
#         -6.29618317e-02, -4.23223991e-03, -2.45864540e-02,
#          4.69742566e-02, -4.72128950e-02, -2.43663266e-02,
#         -5.47670536e-02, -6.27434030e-02, -9.30075068e-03,
#         -1.05388006e-02,  2.26782896e-02, -1.03660569e-01,
#          8.82882476e-02,  5.99627905e-02, -3.86280641e-02,
#          6.20167144e-03,  2.22931564e-01,  1.76062100e-02,
#          1.02184698e-01, -7.51681626e-02,  1.15652665e-01,
#          2.24483060e-03, -5.09309815e-03, -4.04202193e-02,
#          1.41840531e-02,  3.29508148e-02,  8.55511874e-02,
#          9.97747779e-02, -1.88774371e-03, -1.18686380e-02,
#          2.20029578e-02,  2.65222397e-02,  7.39746913e-02,
#         -4.47563231e-02,  2.99760960e-02,  4.51344950e-03,
#          8.93076416e-03,  2.31540240e-02,  7.33993798e-02,
#          7.44567160e-03, -7.50556542e-03,  4.78728116e-02,
#         -3.81070785e-02, -1.21835107e-02, -2.94260122e-02,
#          3.54673937e-02, -7.80467689e-02,  1.59752637e-01,
#         -2.77504008e-02, -6.75272495e-02,  3.04672085e-02,
#          4.42437641e-02, -9.43766255e-03,  1.15473256e-01,
#          3.52858417e-02,  2.30935100e-03,  1.53233305e-01,
#         -7.51670748e-02,  5.90606220e-02, -4.82583381e-02,
#         -9.63795409e-02,  6.16557822e-02, -4.69012782e-02,
#          2.98030674e-02, -9.45186801e-03, -2.96701342e-02,
#         -1.93574093e-02,  7.06204548e-02, -2.55906954e-02,
#          6.26778230e-02, -6.92919418e-02,  1.90218713e-03,
#         -7.48000666e-02, -5.98950125e-02, -1.47139151e-02,
#         -6.81942105e-02, -1.76987369e-02, -3.12879384e-02,
#          2.37400550e-02, -5.86721338e-02, -1.22129805e-01,
#         -9.85100493e-03,  1.95855293e-02,  2.57337913e-02,
#          4.98900600e-02, -2.28401199e-02,  2.66355574e-02,
#          2.64788568e-02, -5.98777900e-04,  1.24796823e-01,
#          8.70417710e-03, -3.02441232e-02,  7.60593042e-02],
#        [-5.36967777e-02, -1.13776095e-01,  8.59237760e-02,
#         -3.76470312e-02,  2.46917978e-02,  5.76743372e-02,
#          7.37135783e-02,  6.07750714e-02,  7.86938667e-02,
#          5.07763401e-02, -1.47773940e-02,  4.11182642e-02,
#         -6.30205497e-02,  1.26474917e-01,  7.77265802e-03,
#          3.65164801e-02, -5.02463318e-02, -2.94462487e-04,
#          9.73765459e-03, -1.26728667e-02, -5.60959466e-02,
#         -4.71653715e-02, -7.16525763e-02,  2.46794093e-02,
#         -2.79582813e-02,  5.17707914e-02, -3.21432315e-02,
#         -4.29401398e-02,  1.44794509e-01, -4.98190969e-02,
#         -2.60703638e-02, -5.29701123e-03, -2.82457117e-02,
#         -7.94266313e-02, -5.85975200e-02,  4.47554048e-04,
#         -3.46525796e-02, -1.36716571e-02, -6.71137422e-02,
#         -1.65627711e-02, -2.53018923e-02, -1.03412695e-01,
#          7.49800205e-02,  4.04207874e-03, -1.04264421e-02,
#         -1.88776050e-02,  1.94926206e-02, -1.23113118e-01,
#          1.28085995e-02, -1.76224373e-02, -9.78943557e-02,
#          1.72559805e-02,  6.63190633e-02, -8.53682160e-02,
#         -8.83621722e-02, -6.70987554e-03, -5.95882395e-03,
#          1.35693952e-01,  4.42417972e-02, -1.24973655e-01,
#         -1.63160022e-02,  1.43962717e-02,  6.70857262e-03,
#          2.80171726e-02,  5.64631857e-02, -8.31234455e-02,
#         -3.06254777e-04,  3.02926656e-02, -5.63824847e-02,
#         -6.47873729e-02, -8.59654844e-02, -1.59778640e-01,
#         -8.96283984e-03, -1.37823005e-03, -4.28729430e-02,
#          2.62533198e-03, -3.52368481e-03, -3.19383480e-02,
#          5.34959957e-02, -2.39102542e-02,  7.72500113e-02,
#         -8.13523890e-04,  5.25789186e-02, -9.95713547e-02,
#          1.13946991e-02,  6.96138442e-02, -5.99062480e-02,
#         -7.67027959e-02, -5.37838228e-02, -6.61967173e-02,
#          3.59628499e-02,  2.58516520e-02,  1.11112371e-02,
#         -4.82172556e-02, -4.90247458e-03,  4.28368598e-02,
#         -3.94228920e-02, -1.01406045e-01,  1.29404366e-01,
#          1.10125847e-01,  1.19369425e-01,  1.24752778e-03,
#          1.45916581e-01,  1.27376884e-03, -2.28895359e-02,
#          1.71541311e-02,  6.39035925e-02,  1.76334325e-02,
#         -5.37031144e-02,  7.58519545e-02,  6.06172793e-02,
#         -4.27371189e-02, -9.31196883e-02, -4.16145809e-02,
#         -6.55004904e-02,  9.92464721e-02, -3.74250636e-02,
#         -6.12693094e-02, -1.85362492e-02, -1.32022034e-02,
#         -5.88023663e-02, -4.76345941e-02, -3.92467715e-02,
#         -9.32278018e-03, -1.70415156e-02,  8.69811550e-02,
#          6.05870709e-02,  5.48287816e-02, -7.73089333e-03,
#          4.28406848e-03, -6.25253171e-02,  4.50419188e-02,
#          4.32497039e-02,  1.77303944e-02,  3.43691073e-02,
#         -2.39612330e-02, -2.88137402e-02,  2.40826290e-02,
#          3.12523544e-02,  1.60948781e-03, -5.69804013e-02,
#          4.73273126e-03,  4.14725617e-02,  1.06262239e-02,
#          5.28437160e-02, -1.05777886e-02,  1.19013758e-02,
#         -5.34310006e-04,  4.79283277e-03,  1.13622680e-01,
#          5.29448781e-03,  4.92714345e-02, -4.53315042e-02,
#          5.45232855e-02,  7.64236785e-03,  6.96058273e-02,
#         -1.74322259e-02,  6.59484696e-03,  9.75806173e-03,
#         -7.17462897e-02,  4.19579856e-02, -5.40005043e-02,
#         -9.47139226e-03,  1.03681885e-01,  6.36797678e-03,
#         -1.59178406e-01,  1.69651452e-02, -1.04298681e-01,
#         -3.87316048e-02, -3.51831177e-03,  1.62283685e-02,
#          3.72226648e-02, -5.55261970e-03,  5.42952046e-02,
#         -4.16527763e-02, -1.82076637e-02,  7.44541502e-03,
#         -7.45831653e-02, -6.93104267e-02,  1.23422705e-01,
#          1.57993473e-02, -1.96126010e-02, -6.41937833e-03,
#         -7.81059414e-02,  9.17602256e-02, -3.95141169e-02,
#         -8.35488811e-02, -7.85507336e-02, -4.97958437e-02,
#         -4.49065752e-02, -3.79686281e-02,  2.24858783e-02,
#          8.70300904e-02,  6.21311180e-03, -8.42666104e-02,
#         -5.18171340e-02,  5.33689093e-03,  1.07768746e-02,
#         -7.27125928e-02, -2.73579899e-02,  1.23603940e-01,
#          5.15629537e-02, -7.04294518e-02,  4.82127145e-02,
#          8.47527664e-03,  6.23321868e-02, -8.07147324e-02,
#         -3.49688791e-02, -4.03391793e-02, -5.52927628e-02,
#         -1.95290372e-02,  7.60007044e-03, -5.13578691e-02,
#         -2.48311814e-02, -3.04902028e-02,  1.55121945e-02,
#          9.92303342e-03,  9.11468267e-02, -4.20966111e-02,
#          1.68919523e-05,  1.33002829e-02, -2.07525399e-02,
#          1.27512179e-02,  2.05558300e-01,  4.50788029e-02,
#          2.74187583e-03,  2.02926192e-02,  5.57471737e-02,
#          1.14677310e-01,  2.52573169e-03, -5.07384092e-02,
#          2.25109421e-02,  8.95202830e-02,  8.54032487e-02,
#          6.65976107e-02,  5.18683195e-02,  2.08674073e-02,
#          6.68465048e-02,  1.01405866e-02,  7.42222043e-03,
#         -2.58077886e-02,  1.73250977e-02,  6.69513047e-02,
#         -3.39709409e-02,  4.93071377e-02,  7.17476085e-02,
#         -2.13788124e-03, -1.02337161e-02,  6.63803518e-03,
#         -3.79069373e-02, -8.85570794e-02, -5.75942881e-02,
#         -1.34606985e-02,  5.90466941e-03,  6.30611181e-02,
#         -1.27021624e-02, -6.18486069e-02, -6.23333193e-02,
#          3.11305504e-02,  8.53418112e-02, -1.86966266e-02,
#          9.33616683e-02,  1.40657872e-02,  3.48297171e-02,
#         -4.84331250e-02,  5.40453531e-02, -3.84156592e-02,
#         -5.38946837e-02, -4.81992289e-02, -2.01148316e-02,
#          2.14211177e-02, -9.87557322e-03, -3.03348675e-02,
#          1.07841544e-01, -1.84270774e-03,  1.75281372e-02,
#          7.00440407e-02, -8.49215686e-02, -1.20833353e-03,
#         -2.95289438e-02,  1.72530022e-02, -5.10975048e-02,
#         -4.61176671e-02, -4.53996323e-02, -3.77051495e-02,
#          4.45789136e-02, -2.27769837e-02, -1.31560683e-01,
#          1.01779411e-02,  1.99069362e-02,  2.99649853e-02,
#          1.72319356e-02, -2.78069805e-02,  1.77846234e-02,
#         -2.92708483e-02, -4.30690907e-02,  1.20161168e-01,
#          1.79259870e-02, -5.63173071e-02,  1.49791375e-01],
#        [ 3.13800722e-02, -1.54366076e-01,  1.22692436e-01,
#         -5.05227186e-02, -6.95590535e-03,  6.93243593e-02,
#          1.78719591e-02,  3.21024172e-02,  4.85388823e-02,
#          5.59323132e-02,  6.97236732e-02,  7.43501708e-02,
#         -7.91906118e-02,  1.43905580e-01,  2.36414140e-03,
#          1.12307966e-01, -6.99554086e-02, -4.26423457e-03,
#          1.15060061e-02,  3.25160543e-03, -4.88908216e-02,
#         -1.87912211e-02, -6.25167564e-02,  9.00314655e-03,
#         -2.48670839e-02,  3.17267999e-02,  1.24559586e-03,
#         -3.19834948e-02,  1.04932403e-02, -5.19335270e-04,
#         -1.85525436e-02, -4.51349840e-02, -3.53702903e-02,
#         -9.06551480e-02, -1.20677380e-02, -6.17769621e-02,
#         -2.30356958e-02,  2.94839386e-02, -1.10800946e-02,
#         -6.48974851e-02, -5.06212749e-02, -1.92777552e-02,
#          7.44239613e-02, -7.43783414e-02, -1.99722331e-02,
#          3.50298081e-03, -1.17329977e-01, -3.69583741e-02,
#         -1.17324768e-02,  4.27034497e-02, -2.11584251e-02,
#          9.20968056e-02,  1.01123460e-01, -3.90902311e-02,
#         -1.70824453e-02, -4.17238995e-02,  2.41838172e-02,
#          6.53604791e-02, -5.42822927e-02, -1.38766691e-01,
#         -6.34568557e-02,  2.91888788e-02,  9.18634906e-02,
#         -7.08733201e-02,  9.90890935e-02, -4.34052758e-02,
#         -5.60770417e-03,  2.33407691e-02,  5.81881180e-02,
#          6.03783540e-02, -2.37060394e-02, -3.25235091e-02,
#          1.18674925e-02,  4.98163216e-02, -8.97987708e-02,
#         -3.88426743e-02, -2.39199195e-02, -7.20281303e-02,
#         -7.54752383e-03, -6.05626777e-02,  6.12439476e-02,
#          1.55313453e-02,  2.91406792e-02, -7.44818971e-02,
#          2.85611767e-02,  1.08643420e-01, -4.59097624e-02,
#         -3.94724263e-03, -4.45437841e-02, -5.22535220e-02,
#         -2.01945156e-02, -2.69475095e-02, -5.66212498e-02,
#          1.92922342e-03, -1.23168100e-02,  2.84397509e-03,
#         -9.91978869e-02, -9.47082192e-02,  7.96226263e-02,
#          6.07126914e-02,  1.28418580e-01,  3.96671332e-02,
#          8.25566351e-02, -2.46465318e-02, -2.37252861e-02,
#          1.38437068e-02, -4.63658059e-03, -5.67016192e-02,
#         -8.65378696e-03,  1.83569398e-02,  2.62256991e-02,
#          4.12552841e-02, -1.01781525e-01, -4.43654396e-02,
#          3.27805877e-02,  1.75809786e-02,  1.67539977e-02,
#         -8.40443894e-02, -1.63042128e-01,  4.66073714e-02,
#         -1.14108488e-01, -1.09421156e-01, -3.59049849e-02,
#          1.81378555e-02,  1.80036593e-02,  5.32481708e-02,
#          7.24546388e-02,  9.14459303e-02,  4.10404801e-02,
#          1.07180118e-03, -2.95849293e-02,  4.36185487e-02,
#         -3.97061370e-02,  5.47587126e-02,  4.91735637e-02,
#         -3.46084498e-02, -8.06709602e-02,  9.25264135e-03,
#          2.86795199e-02, -4.43080999e-02, -7.87696689e-02,
#          3.38030122e-02,  5.24448156e-02,  2.65701227e-02,
#          2.79800091e-02,  6.12052064e-03, -3.62314656e-03,
#          4.19897437e-02,  3.47282737e-02,  8.36568177e-02,
#          1.25924041e-02,  2.35346742e-02, -1.60073172e-02,
#          9.10817608e-02, -4.89350315e-03,  6.40222728e-02,
#         -1.20484419e-02, -1.52213443e-02, -6.95903925e-03,
#         -3.98642197e-02,  1.02566695e-02, -3.25030759e-02,
#          1.20800519e-02,  2.56343670e-02, -2.90686805e-02,
#         -1.68023720e-01, -1.51388887e-02, -7.48857558e-02,
#          5.44348136e-02, -5.38804568e-02,  5.55698611e-02,
#          5.73136173e-02,  8.12680344e-04, -2.44896505e-02,
#         -1.18413754e-01, -3.82314399e-02, -1.14026880e-02,
#         -1.91109441e-02,  1.16246892e-02,  4.85884175e-02,
#          3.25721800e-02,  6.84017688e-02,  3.17240916e-02,
#          7.94456806e-03,  1.14677124e-01,  5.62659185e-03,
#         -6.15697280e-02, -1.02532469e-01, -3.02772541e-02,
#         -3.39412428e-02, -4.18552607e-02, -9.94085148e-02,
#          2.20678523e-02, -9.93033987e-04, -3.38947251e-02,
#         -1.90287493e-02, -1.28201814e-02,  5.91711095e-03,
#          3.12089138e-02,  3.32698449e-02,  1.32635430e-01,
#          1.76975559e-02,  1.69798778e-03, -2.96767056e-02,
#         -1.85475498e-02,  8.61197412e-02,  2.66704094e-02,
#         -9.64836255e-02, -4.06596698e-02,  1.91783793e-02,
#          1.38850324e-02, -3.21028791e-02, -8.66472255e-03,
#         -6.09388463e-02, -7.58535713e-02,  2.45346744e-02,
#         -1.88887622e-02, -4.11542319e-03, -9.79734436e-02,
#          4.86961827e-02,  4.33761179e-02, -5.61320074e-02,
#          6.54806495e-02,  1.99358761e-01,  4.22914978e-03,
#          4.80242372e-02, -6.47989884e-02,  9.50186625e-02,
#          6.34684041e-02, -3.98830790e-03, -5.03476895e-02,
#          2.18613781e-02,  2.70790793e-02,  9.67294052e-02,
#          7.53933564e-02, -1.01823434e-02, -2.72847861e-02,
#          5.82319871e-03,  5.41120581e-02,  4.92162816e-02,
#         -9.76375788e-02,  3.86886895e-02,  1.07948715e-02,
#          5.54673700e-03,  1.36598377e-02,  9.10063013e-02,
#          1.93684809e-02, -1.33612063e-02,  1.60144344e-02,
#         -2.48543676e-02, -8.75195675e-03, -6.45289496e-02,
#          6.41385838e-03, -9.16278139e-02,  1.61998123e-01,
#         -4.97093089e-02, -2.24860590e-02,  3.19040641e-02,
#          4.00279388e-02, -2.09424067e-02,  1.35122120e-01,
#          4.65259477e-02, -3.79648954e-02,  1.77465752e-01,
#         -6.60149902e-02,  4.27570455e-02, -3.36205587e-02,
#         -1.06206022e-01,  6.51933625e-02, -4.54410724e-02,
#          4.54630479e-02, -7.23145623e-03,  2.53107548e-02,
#          2.21509673e-03,  4.32951525e-02, -4.44645546e-02,
#          2.95228176e-02, -3.98392342e-02,  1.34773180e-02,
#         -7.69596323e-02, -2.12260932e-02, -1.45610617e-02,
#         -2.40939222e-02,  1.01650646e-02, -4.62208800e-02,
#          2.48410515e-02, -5.89275397e-02, -6.82676882e-02,
#         -1.88157056e-02,  1.74790919e-02,  3.42760943e-02,
#          1.79794654e-02,  1.96264628e-02,  1.91985294e-02,
#          5.44444397e-02,  2.82501560e-02,  8.50663483e-02,
#         -1.93429440e-02, -5.68174478e-03,  8.59841034e-02]], dtype=float32)

# %%
from sklearn import cluster
from sklearn import metrics

kmeans = cluster.KMeans(n_clusters=100)
kmeans.fit(word_vectors.vectors)
# Out:
# KMeans(n_clusters=100)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
 
print ("Cluster id labels for inputted data")
print (labels)
print ("Centroids data")
print (centroids)
 
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(word_vectors.vectors))
 
silhouette_score = metrics.silhouette_score(word_vectors.vectors, labels, metric='euclidean')
 
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Cluster id labels for inputted data
# [86 86 86 ... 80 80 38]
# Centroids data
# [[-1.4229143e-02  5.4488074e-02 -2.9263087e-02 ... -4.0387928e-02
#   -6.1845523e-03  2.7498739e-02]
#  [-3.6121428e-02  5.3280719e-02  1.0692533e-03 ... -2.9216185e-02
#   -9.8252585e-03 -5.8435071e-02]
#  [-1.3149026e-03  7.2861195e-02 -2.5657862e-02 ... -8.4208325e-05
#   -2.5520120e-02  2.3659438e-02]
#  ...
#  [-5.2355332e-03  1.4409461e-02 -3.6562506e-02 ... -1.5763134e-02
#   -1.5947366e-02  4.6983985e-03]
#  [-1.1164323e-02  3.6268219e-02 -7.9611905e-02 ...  3.7073713e-02
#   -3.6960125e-02  1.3007020e-02]
#  [ 1.1379392e-02  7.3280573e-02 -1.9985575e-02 ... -2.4762683e-02
#   -7.8482740e-04 -4.8240643e-02]]
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -22674.505859375
# Silhouette_score:
# 0.004092729

# %%
word_vectors.get_vecattr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-905bb8d7d9ab> in <module>
# ----> 1 word_vectors.get_vecattr('락')
#
# TypeError: get_vecattr() missing 1 required positional argument: 'attr'

# %%
kmeans.predict()
